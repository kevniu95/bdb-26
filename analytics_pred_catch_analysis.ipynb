# %%
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
from pathlib import Path
from tqdm.auto import tqdm
import os
from typing import List

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GroupKFold
from sklearn.cluster import KMeans
from multiprocessing import Pool as MultiprocessingPool, cpu_count

from src.kinematics import calculate_speed_and_direction

pd.set_option("display.max_columns", None)

# %%
# ============================================================================
# CONFIG
# ============================================================================

class Config:
    DATA_DIR = Path("./data")
    OUTPUT_DIR = Path("./outputs")
    OUTPUT_DIR.mkdir(exist_ok=True)
    
    SEED = 42
    N_FOLDS = 5
    BATCH_SIZE = 256
    EPOCHS = 60
    PATIENCE = 30
    LEARNING_RATE = 1e-4
    
    WINDOW_SIZE = 10
    HIDDEN_DIM = 128
    MAX_FUTURE_HORIZON = 94
    
    FIELD_X_MIN, FIELD_X_MAX = 0.0, 120.0
    FIELD_Y_MIN, FIELD_Y_MAX = 0.0, 53.3
    
    K_NEIGH = 6
    RADIUS = 30.0
    TAU = 8.0
    N_ROUTE_CLUSTERS = 7
    
    DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

def set_seed(seed=42):
    import random
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)

set_seed(Config.SEED)

# %%
config = Config()
config

print("\n[1/4] Loading data...")
train_input_files = [config.DATA_DIR / f"train/input_2023_w{w:02d}.csv" for w in range(1, 19)]
train_output_files = [config.DATA_DIR / f"train/output_2023_w{w:02d}.csv" for w in range(1, 19)]
train_input = pd.concat([pd.read_csv(f) for f in train_input_files if f.exists()])
train_output = pd.concat([pd.read_csv(f) for f in train_output_files if f.exists()])
supplementary_data = pd.read_csv(config.DATA_DIR / "supplementary_data.csv")

print(f"✓ Train input: {train_input.shape}, Train output: {train_output.shape}")
print(f"✓ Train output: {train_output.shape}, unique plays: {train_output[['game_id','play_id']].drop_duplicates().shape[0]}")
print(f"✓ Supplementary data: {supplementary_data.shape}")

traj_output = pd.read_csv('local_submission.csv')
traj_output = traj_output[['game_id', 'play_id', 'nfl_id', 'frame_id', 'pred_x', 'pred_y']]
traj_output.rename(columns={'pred_x': 'x', 'pred_y': 'y'}, inplace=True)

train_output.sort_values(by=['game_id', 'play_id', 'nfl_id', 'frame_id'], inplace=True)
traj_output.sort_values(by=['game_id', 'play_id', 'nfl_id', 'frame_id'], inplace=True)

print(f"✓ Projected trajectory output: {traj_output.shape}, unique plays: {traj_output[['game_id','play_id']].drop_duplicates().shape[0]}")
# Out:
# [1/4] Loading data...
# /var/folders/_m/rvnpg_cs6xzcz0vlml0lzkbm0000gp/T/ipykernel_41316/1380030048.py:9: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   supplementary_data = pd.read_csv(config.DATA_DIR / "supplementary_data.csv")
# ✓ Train input: (4880579, 23), Train output: (562936, 6)
# ✓ Train output: (562936, 6), unique plays: 14108
# ✓ Supplementary data: (18009, 41)
# ✓ Projected trajectory output: (562936, 6), unique plays: 14108

# %%
local_submission = pd.read_csv('local_submission.csv')
a = train_input[['game_id','play_id','nfl_id','player_role']].drop_duplicates()
labeled_output = train_output.merge(a, on=['game_id','play_id','nfl_id'], how='left')
print(labeled_output.shape)
labeled_output.head()

keys = ['game_id','play_id','nfl_id','frame_id']
loc_sub_cols = keys + ['pred_x','pred_y']
labeled_output = labeled_output.merge(local_submission[loc_sub_cols], on=['game_id','play_id','nfl_id','frame_id'], how='left', suffixes=('_true','_pred'))
labeled_output['error'] = np.sqrt((labeled_output['x'] - labeled_output['pred_x'])**2 + (labeled_output['y'] - labeled_output['pred_y'])**2)
labeled_output['error_diff'] = labeled_output.groupby(['game_id', 'play_id', 'nfl_id'])['error'].diff()
labeled_output.head(20)

receiver_positions = labeled_output.loc[
  labeled_output['player_role'] == 'Targeted Receiver',
  ['game_id','play_id','nfl_id', 'frame_id','x','y']].drop_duplicates()
receiver_positions.rename(columns = {'x':'target_x', 'y':'target_y'}, inplace = True)
print(receiver_positions.shape)
receiver_positions.head(3)

labeled_output = labeled_output.merge(
    receiver_positions[['game_id','play_id','frame_id','target_x','target_y']],
    on=['game_id','play_id','frame_id'], how='left'
)
print(labeled_output.shape)
labeled_output.head(3)

labeled_output['distance_from_receiver'] = np.sqrt(
    (labeled_output['x'] - labeled_output['target_x'])**2 +
    (labeled_output['y'] - labeled_output['target_y'])**2
)

# labeled_output['distance_from_receiver_l1'] = labeled_output.groupby(['game_id', 'play_id', 'nfl_id'])['distance_from_receiver'].shift(1)
labeled_output['distance_from_receiver_l3'] = labeled_output.groupby(['game_id', 'play_id', 'nfl_id'])['distance_from_receiver'].shift(3)
labeled_output['distance_from_receiver_l5'] = labeled_output.groupby(['game_id', 'play_id', 'nfl_id'])['distance_from_receiver'].shift(5)
labeled_output['distance_from_receiver_l7'] = labeled_output.groupby(['game_id', 'play_id', 'nfl_id'])['distance_from_receiver'].shift(7)

labeled_output['distance_from_receiver_min_l7'] = labeled_output[[
                                                                # 'distance_from_receiver',
                                                                # 'distance_from_receiver_l1',
                                                                'distance_from_receiver_l3',
                                                                'distance_from_receiver_l5',
                                                                'distance_from_receiver_l7']].min(axis=1) 
labeled_output[
  (labeled_output['game_id'] == 2023091013) &
  (labeled_output['play_id'] == 3686) &
  (labeled_output['nfl_id'] == 54632)
]

# test = labeled_output[labeled_output['player_role'].str.contains('Defensive Coverage')]
# Out:
# (562936, 7)
# (160360, 6)
# (562936, 13)
#           game_id  play_id  nfl_id  frame_id      x      y  \
# 29621  2023091013     3686   54632         1  46.63  39.84
# 29622  2023091013     3686   54632         2  46.44  40.36
# 29623  2023091013     3686   54632         3  46.22  40.96
# 29624  2023091013     3686   54632         4  46.02  41.48
# 29625  2023091013     3686   54632         5  45.79  42.05
# 29626  2023091013     3686   54632         6  45.58  42.56
# 29627  2023091013     3686   54632         7  45.29  43.15
# 29628  2023091013     3686   54632         8  45.08  43.63
# 29629  2023091013     3686   54632         9  44.67  44.28
# 29630  2023091013     3686   54632        10  43.99  45.14
# 29631  2023091013     3686   54632        11  43.39  45.93
#
#               player_role     pred_x     pred_y     error  error_diff  \
# 29621  Defensive Coverage  46.631927  39.860932  0.021020         NaN
# 29622  Defensive Coverage  46.512623  40.263906  0.120450    0.099430
# 29623  Defensive Coverage  46.370215  40.694341  0.305187    0.184738
# 29624  Defensive Coverage  46.206613  41.154565  0.375143    0.069956
# 29625  Defensive Coverage  46.025641  41.638732  0.473992    0.098849
# 29626  Defensive Coverage  45.828163  42.145513  0.483099    0.009107
# 29627  Defensive Coverage  45.614781  42.675000  0.575419    0.092321
# 29628  Defensive Coverage  45.398282  43.220472  0.518668   -0.056751
# 29629  Defensive Coverage  45.166847  43.777821  0.706428    0.187759
# 29630  Defensive Coverage  44.927816  44.349732  1.226386    0.519958
# 29631  Defensive Coverage  44.688884  44.921010  1.644737    0.418351
#
#        target_x  target_y  distance_from_receiver  distance_from_receiver_l3  \
# 29621     43.87     40.61                2.865397                        NaN
# 29622     43.89     41.11                2.658007                        NaN
# 29623     43.88     41.61                2.428600                        NaN
# 29624     43.84     42.13                2.274841                   2.865397
# 29625     43.77     42.64                2.104400                   2.658007
# 29626     43.68     43.15                1.989497                   2.428600
# 29627     43.58     43.66                1.784433                   2.274841
# 29628     43.46     44.18                1.710819                   2.104400
# 29629     43.30     44.73                1.442012                   1.989497
# 29630     43.16     45.23                0.834865                   1.784433
# 29631     42.99     45.72                0.451774                   1.710819
#
#        distance_from_receiver_l5  distance_from_receiver_l7  \
# 29621                        NaN                        NaN
# 29622                        NaN                        NaN
# 29623                        NaN                        NaN
# 29624                        NaN                        NaN
# 29625                        NaN                        NaN
# 29626                   2.865397                        NaN
# 29627                   2.658007                        NaN
# 29628                   2.428600                   2.865397
# 29629                   2.274841                   2.658007
# 29630                   2.104400                   2.428600
# 29631                   1.989497                   2.274841
#
#        distance_from_receiver_min_l7
# 29621                            NaN
# 29622                            NaN
# 29623                            NaN
# 29624                       2.865397
# 29625                       2.658007
# 29626                       2.428600
# 29627                       2.274841
# 29628                       2.104400
# 29629                       1.989497
# 29630                       1.784433
# 29631                       1.710819

# %%
labeled_output['potential_contact'] = np.where(
  (
    (labeled_output['player_role'] == 'Defensive Coverage') & 
    (labeled_output['error_diff'] > 0.1) & 
    (labeled_output['distance_from_receiver_min_l7'] < 1.25)
  ),
  1, 0
)


potential_contact = labeled_output.groupby(['game_id','play_id','nfl_id']).max()['potential_contact'].reset_index()
potential_contact['potential_contact'].value_counts()
# Out:
# potential_contact
# 0    44540
# 1     1505
# Name: count, dtype: int64

# %%
# Get max frame_id for each player in each play (no warnings)
final_positions = (
    train_input
    .sort_values('frame_id')
    .groupby(['game_id', 'play_id', 'nfl_id'], as_index=False)
    .last()
    [['game_id', 'play_id', 'nfl_id', 'frame_id', 'x', 'y', 'player_role', 'ball_land_x', 'ball_land_y']]
)

# Calculate angle to ball landing spot
final_positions['angle_to_ball'] = np.degrees(np.arctan2(
    final_positions['ball_land_y'] - final_positions['y'],
    final_positions['ball_land_x'] - final_positions['x']
))

# Distance to ball
final_positions['distance_to_ball'] = np.sqrt(
    (final_positions['ball_land_x'] - final_positions['x'])**2 + 
    (final_positions['ball_land_y'] - final_positions['y'])**2
)

# Get targeted receiver positions AND angle
targeted_receivers = final_positions[
    final_positions['player_role'] == 'Targeted Receiver'
][['game_id', 'play_id', 'x', 'y', 'angle_to_ball']].rename(
    columns={
        'x': 'target_x', 
        'y': 'target_y',
        'angle_to_ball': 'target_angle_to_ball'
    }
)

# Merge back to get targeted receiver position for each play
final_positions = final_positions.merge(
    targeted_receivers,
    on=['game_id', 'play_id'],
    how='left'
)

# Calculate distance to targeted receiver
final_positions['distance_to_target_receiver'] = np.sqrt(
    (final_positions['target_x'] - final_positions['x'])**2 + 
    (final_positions['target_y'] - final_positions['y'])**2
)

# Calculate angle difference from targeted receiver
# Handle angle wrapping (e.g., difference between 359° and 1° should be 2°, not 358°)
angle_diff = final_positions['angle_to_ball'] - final_positions['target_angle_to_ball']
final_positions['angle_diff_from_target'] = np.where(
    angle_diff > 180, 
    angle_diff - 360,
    np.where(angle_diff < -180, angle_diff + 360, angle_diff)
)

# Absolute angle difference (unsigned)
final_positions['abs_angle_diff_from_target'] = np.abs(final_positions['angle_diff_from_target'])

# Optional: drop intermediate columns
final_positions = final_positions.drop(columns=['target_x', 'target_y', 'target_angle_to_ball'])

final_positions['defender_type'] = np.where((final_positions['distance_to_target_receiver'] < 6.0) &
                                            (final_positions['player_role'].str.contains('Defensive Coverage')) &
                                            (final_positions['abs_angle_diff_from_target'] < 90.0)
                                            , 'Trailing', np.where((final_positions['player_role'].str.contains('Defensive Coverage'))
                                                                   , 'Converging', None))

final_positions.sort_values(['game_id','play_id','nfl_id'], inplace=True)
print(f"Shape: {final_positions.shape}")
final_positions.head(3)
# Out:
# Shape: (173150, 15)
#       game_id  play_id  nfl_id  frame_id      x      y         player_role  \
# 0  2023090700      101   43290        26  35.41  29.99              Passer
# 1  2023090700      101   44930        26  52.43  14.14   Targeted Receiver
# 2  2023090700      101   46137        26  55.82  17.67  Defensive Coverage
#
#    ball_land_x  ball_land_y  angle_to_ball  distance_to_ball  \
# 0    63.259998        -0.22     -47.327657         41.088520
# 1    63.259998        -0.22     -52.977199         17.986063
# 2    63.259998        -0.22     -67.418810         19.375388
#
#    distance_to_target_receiver  angle_diff_from_target  \
# 0                    23.257319                5.649543
# 1                     0.000000                0.000000
# 2                     4.894180              -14.441611
#
#    abs_angle_diff_from_target defender_type
# 0                    5.649543          None
# 1                    0.000000          None
# 2                   14.441611      Trailing

# %%
final_positions.rename(columns={'x': 'throw_x', 'y': 'throw_y'}, inplace=True)
defender_type = train_output[['game_id','play_id','nfl_id']].drop_duplicates().merge(
    final_positions[['game_id','play_id','nfl_id','player_role','angle_to_ball','throw_x','throw_y','distance_to_ball', 'distance_to_target_receiver', 'abs_angle_diff_from_target', 'defender_type']],
    on=['game_id','play_id','nfl_id'], how='left'
)
print(defender_type.shape)
defender_type.tail(3)
# Out:
# (46045, 11)
#           game_id  play_id  nfl_id         player_role  angle_to_ball  \
# 46042  2024010713     4018   47844  Defensive Coverage     -80.352611
# 46043  2024010713     4018   52457   Targeted Receiver    -120.931741
# 46044  2024010713     4018   52647  Defensive Coverage    -152.507915
#
#        throw_x  throw_y  distance_to_ball  distance_to_target_receiver  \
# 46042    30.69    15.24          8.652364                     8.013588
# 46043    38.45    17.24         12.275871                     0.000000
# 46044    44.40    13.09         13.820710                     7.254309
#
#        abs_angle_diff_from_target defender_type
# 46042                   40.579130    Converging
# 46043                    0.000000          None
# 46044                   31.576174    Converging

# %%
def map_route_family(route: str) -> str:
    """
    For field named: route_type_of_targeted_receiver
    """
    if pd.isna(route):
        return "UNKNOWN"
    route = str(route).upper()
    
    vertical = {"GO", "POST", "CORNER", "WHEEL"}
    out_break = {"OUT", "FLAT"}
    in_break = {"IN", "SLANT", "CROSS", "ANGLE"}
    stop = {"HITCH"}
    screen = {"SCREEN"}
    
    if route in vertical:
        return "VERTICAL"
    if route in out_break:
        return "OUT_BREAK"
    if route in in_break:
        return "IN_BREAK"
    if route in stop:
        return "STOP_HITCH"
    if route in screen:
        return "SCREEN"
    return "OTHER"

def classify_down_distance(down, distance):
    """
    Classify down/distance into meaningful football situations.

    Returns compact labels like '3rd_long', '1st_short', etc.
    """
    if pd.isna(down) or pd.isna(distance):
        return "unknown"

    # Distance buckets
    if distance <= 3:
        dist_label = "short"
    elif distance <= 7:
        dist_label = "medium"
    else:
        dist_label = "long"

    # Special cases
    if down == 3 and distance >= 10:
        return "3rd_long"  # Most predictive situation
    elif down == 4:
        return "4th_down"  # All 4th downs are high-leverage
    elif down == 1 and distance <= 3:
        return "1st_short"  # Run-heavy
    elif down == 2 and distance >= 10:
        return "2nd_long"  # Pass-heavy
    else:
        return (
            f'{int(down)}{"st" if down==1 else "nd" if down==2 else "rd"}_{dist_label}'
        )


def bin_pass_length(pl):
    """
    pl: numeric pass_length (air yards)
    Bins: SHORT (0-10), INTERMEDIATE (10-20), DEEP (20+)
    """
    if pd.isna(pl):
        return "UNKNOWN"
    try:
        v = float(pl)
    except Exception:
        return "UNKNOWN"
    
    if v <= 10:
        return "SHORT"
    elif v <= 20:
        return "INTERMEDIATE"
    else:
        return "DEEP"

def prep_supplementary_data_for_icc(supplementary_data:pd.DataFrame) -> pd.DataFrame:
    supplementary_data["down_and_distance"] = supplementary_data.apply(
        lambda row: classify_down_distance(row["down"], row["yards_to_go"]), axis=1
    )

    supplementary_data["route_type_of_targeted_receiver"] = supplementary_data[
        "route_of_targeted_receiver"
    ].apply(map_route_family)

    supplementary_data["pass_length_bin"] = supplementary_data["pass_length"].apply(
        bin_pass_length
    )


    
    suppl_data_pre = supplementary_data[
        [
            "game_id",
            "play_id",
            "possession_team",
            "defensive_team",
            "down_and_distance",
            "receiver_alignment",
            "route_of_targeted_receiver",
            "route_type_of_targeted_receiver",
            "pass_length",
            "pass_length_bin",
            "dropback_type",
            # 'dropback_distance',
            "team_coverage_man_zone",
            "team_coverage_type",
            # "pass_result"
        ]
    ]
    return suppl_data_pre
suppl_data_pre = prep_supplementary_data_for_icc(supplementary_data)
print(suppl_data_pre.shape)
suppl_data_pre.head(3)
# Out:
# (18009, 13)
#       game_id  play_id possession_team defensive_team down_and_distance  \
# 0  2023090700     3461             DET             KC          3rd_long
# 1  2023090700      461             DET             KC          1st_long
# 2  2023090700     1940             DET             KC          2nd_long
#
#   receiver_alignment route_of_targeted_receiver  \
# 0                3x2                         IN
# 1                3x1                       POST
# 2                3x1                        OUT
#
#   route_type_of_targeted_receiver  pass_length pass_length_bin dropback_type  \
# 0                        IN_BREAK           18    INTERMEDIATE   TRADITIONAL
# 1                        VERTICAL           13    INTERMEDIATE   TRADITIONAL
# 2                       OUT_BREAK           18    INTERMEDIATE   TRADITIONAL
#
#   team_coverage_man_zone team_coverage_type
# 0          ZONE_COVERAGE       COVER_2_ZONE
# 1          ZONE_COVERAGE       COVER_6_ZONE
# 2          ZONE_COVERAGE       COVER_2_ZONE

# %%
suppl_data_pre['pass_length_bin'].value_counts()
# Out:
# pass_length_bin
# SHORT           12089
# INTERMEDIATE     3885
# DEEP             2035
# Name: count, dtype: int64

# %%
def bin_air_frames(n_frames):
    """
    n_frames: number of output frames while ball is in the air
    
    Bins by air time:
      QUICK  : <= 10 frames
      MEDIUM : 11-20 frames
      LONG   : > 20 frames
    """
    if pd.isna(n_frames):
        return "UNKNOWN"
    try:
        f = float(n_frames)
    except Exception:
        return "UNKNOWN"
    
    if f <= 10:
        return "QUICK"
    elif f <= 20:
        return "MEDIUM"
    else:
        return "LONG"

def prep_player_level_data_for_icc(
    train_input: pd.DataFrame, train_output: pd.DataFrame
) -> pd.DataFrame:
    qbs = train_input.loc[
        train_input["player_role"] == "Passer", ["game_id", "play_id", "nfl_id"]
    ].drop_duplicates()
    qbs = qbs.rename(columns={"nfl_id": "passer_nfl_id"})

    output_frame_count = (
        train_output.groupby(["game_id", "play_id"])["frame_id"].max().reset_index()
    )
    output_frame_count = output_frame_count.rename(
        columns={"frame_id": "num_output_frames"}
    )
    output_frame_count["num_output_frames_bin"] = output_frame_count[
        "num_output_frames"
    ].apply(bin_air_frames)

    train_input_pre = train_input[
        ["game_id", "play_id", "nfl_id", "player_position"]
    ].drop_duplicates()
    train_input_pre = train_input_pre.merge(qbs, on=["game_id", "play_id"], how="left")
    train_input_pre = train_input_pre.merge(
        output_frame_count, on=["game_id", "play_id"], how="left"
    )
    return train_input_pre

train_input_pre = prep_player_level_data_for_icc(train_input, train_output)
print(train_input_pre.shape)
train_input_pre.head(3)
# Out:
# (173150, 7)
#       game_id  play_id  nfl_id player_position  passer_nfl_id  \
# 0  2023090700      101   54527              FS        43290.0
# 1  2023090700      101   46137              SS        43290.0
# 2  2023090700      101   52546              CB        43290.0
#
#    num_output_frames num_output_frames_bin
# 0                 21                  LONG
# 1                 21                  LONG
# 2                 21                  LONG

# %%
player_impacts = pd.read_csv('./outputs/defender_impact_log_flip.csv')
print(player_impacts.shape)
player_impacts = player_impacts.merge(supplementary_data[['game_id','play_id','pass_result', 'yards_gained', 'season','week','home_team_abbr','visitor_team_abbr','play_description', 'quarter','game_clock']],
        on=['game_id','play_id'], how='left')
print(player_impacts.shape)
player_impacts = player_impacts.merge(train_input_pre,
        on=['game_id','play_id','nfl_id'], how='left')
print(player_impacts.shape)
player_impacts = player_impacts.merge(suppl_data_pre,
        on=['game_id','play_id'], how='left')
print(player_impacts.shape)

player_impacts = player_impacts.merge(defender_type[['game_id','play_id','nfl_id','defender_type']],
                                      on = ['game_id','play_id','nfl_id'],
                                      how = 'left')
print(player_impacts.shape)

player_impacts = player_impacts.merge(potential_contact[['game_id','play_id','nfl_id', 'potential_contact']],
                                      on = ['game_id','play_id','nfl_id'],
                                      how = 'left')
print(player_impacts.shape)

recs = player_impacts.loc[
  player_impacts['player_role'] == 'Targeted Receiver',
  ['game_id','play_id','nfl_id']].drop_duplicates().rename(columns = {'nfl_id':'targeted_receiver_id'})

player_impacts = player_impacts.merge(recs,
                                      on= ['game_id','play_id'],
                                      how = 'left')
print(player_impacts.shape)

player_impacts.sort_values('delta', ascending = False).head(3)
# Out:
# (46045, 8)
# (46045, 17)
# (46045, 21)
# (46045, 32)
# (46045, 33)
# (46045, 34)
# (46045, 35)
#           game_id  play_id  nfl_id        player_role  baseline_prob  \
# 38324  2023091711     1082   55928  Targeted Receiver       0.025208
# 30835  2023101600     4288   47911  Targeted Receiver       0.129202
# 28066  2023091701     3025   41282  Targeted Receiver       0.038386
#
#        real_prob     delta  fold pass_result  yards_gained  season  week  \
# 38324   0.744086  0.718879     5           C            53    2023     2
# 30835   0.775260  0.646058     4           I             0    2023     6
# 28066   0.649082  0.610696     4           I             0    2023     2
#
#       home_team_abbr visitor_team_abbr  \
# 38324            DEN               WAS
# 30835            LAC               DAL
# 28066            BUF                LV
#
#                                         play_description  quarter game_clock  \
# 38324  (13:15) (Shotgun) R.Wilson pass deep left to M...        2      13:15
# 30835  (2:28) (Shotgun) D.Prescott pass incomplete de...        4      02:28
# 28066  (12:57) (Shotgun) J.Garoppolo pass incomplete ...        4      12:57
#
#       player_position  passer_nfl_id  num_output_frames num_output_frames_bin  \
# 38324              WR        38605.0                 27                  LONG
# 30835              RB        43424.0                 23                  LONG
# 28066              WR        41291.0                 17                MEDIUM
#
#       possession_team defensive_team down_and_distance receiver_alignment  \
# 38324             DEN            WAS        3rd_medium                2x2
# 30835             DAL            LAC          3rd_long                3x1
# 28066              LV            BUF         3rd_short                3x1
#
#       route_of_targeted_receiver route_type_of_targeted_receiver  pass_length  \
# 38324                         GO                        VERTICAL           45
# 30835                      WHEEL                        VERTICAL           21
# 28066                         GO                        VERTICAL           17
#
#       pass_length_bin dropback_type team_coverage_man_zone team_coverage_type  \
# 38324            DEEP   TRADITIONAL           MAN_COVERAGE        COVER_1_MAN
# 30835            DEEP   TRADITIONAL          ZONE_COVERAGE       COVER_6_ZONE
# 28066    INTERMEDIATE   TRADITIONAL          ZONE_COVERAGE       COVER_6_ZONE
#
#       defender_type  potential_contact  targeted_receiver_id
# 38324          None                  0                 55928
# 30835          None                  0                 47911
# 28066          None                  0                 41282

# %%
# 2023120304	1700	
player_impacts[(player_impacts['game_id'] == 2023120304)&
                    (player_impacts['play_id'] == 1700)]
# Out:
#           game_id  play_id  nfl_id         player_role  baseline_prob  \
# 23623  2023120304     1700   41233   Targeted Receiver       0.259293
# 23624  2023120304     1700   42816  Defensive Coverage       0.191085
# 23625  2023120304     1700   43341  Defensive Coverage       0.190962
# 23626  2023120304     1700   45004  Defensive Coverage       0.252232
# 23627  2023120304     1700   46124  Defensive Coverage       0.191140
# 23628  2023120304     1700   46527  Defensive Coverage       0.191033
# 23629  2023120304     1700   53437  Defensive Coverage       0.190999
# 23630  2023120304     1700   56230  Defensive Coverage       0.192658
#
#        real_prob     delta  fold pass_result  yards_gained  season  week  \
# 23623   0.190962 -0.068331     3          IN             0    2023    13
# 23624   0.190962 -0.000123     3          IN             0    2023    13
# 23625   0.190962  0.000000     3          IN             0    2023    13
# 23626   0.190962 -0.061270     3          IN             0    2023    13
# 23627   0.190962 -0.000178     3          IN             0    2023    13
# 23628   0.190962 -0.000070     3          IN             0    2023    13
# 23629   0.190962 -0.000037     3          IN             0    2023    13
# 23630   0.190962 -0.001696     3          IN             0    2023    13
#
#       home_team_abbr visitor_team_abbr  \
# 23623             TB               CAR
# 23624             TB               CAR
# 23625             TB               CAR
# 23626             TB               CAR
# 23627             TB               CAR
# 23628             TB               CAR
# 23629             TB               CAR
# 23630             TB               CAR
#
#                                         play_description  quarter game_clock  \
# 23623  (2:31) (Shotgun) B.Mayfield pass deep left int...        2      02:31
# 23624  (2:31) (Shotgun) B.Mayfield pass deep left int...        2      02:31
# 23625  (2:31) (Shotgun) B.Mayfield pass deep left int...        2      02:31
# 23626  (2:31) (Shotgun) B.Mayfield pass deep left int...        2      02:31
# 23627  (2:31) (Shotgun) B.Mayfield pass deep left int...        2      02:31
# 23628  (2:31) (Shotgun) B.Mayfield pass deep left int...        2      02:31
# 23629  (2:31) (Shotgun) B.Mayfield pass deep left int...        2      02:31
# 23630  (2:31) (Shotgun) B.Mayfield pass deep left int...        2      02:31
#
#       player_position  passer_nfl_id  num_output_frames num_output_frames_bin  \
# 23623              WR        46070.0                 27                  LONG
# 23624              CB        46070.0                 27                  LONG
# 23625             ILB        46070.0                 27                  LONG
# 23626              FS        46070.0                 27                  LONG
# 23627              CB        46070.0                 27                  LONG
# 23628             OLB        46070.0                 27                  LONG
# 23629              CB        46070.0                 27                  LONG
# 23630              SS        46070.0                 27                  LONG
#
#       possession_team defensive_team down_and_distance receiver_alignment  \
# 23623              TB            CAR         3rd_short                3x1
# 23624              TB            CAR         3rd_short                3x1
# 23625              TB            CAR         3rd_short                3x1
# 23626              TB            CAR         3rd_short                3x1
# 23627              TB            CAR         3rd_short                3x1
# 23628              TB            CAR         3rd_short                3x1
# 23629              TB            CAR         3rd_short                3x1
# 23630              TB            CAR         3rd_short                3x1
#
#       route_of_targeted_receiver route_type_of_targeted_receiver  pass_length  \
# 23623                         GO                        VERTICAL           28
# 23624                         GO                        VERTICAL           28
# 23625                         GO                        VERTICAL           28
# 23626                         GO                        VERTICAL           28
# 23627                         GO                        VERTICAL           28
# 23628                         GO                        VERTICAL           28
# 23629                         GO                        VERTICAL           28
# 23630                         GO                        VERTICAL           28
#
#       pass_length_bin dropback_type team_coverage_man_zone team_coverage_type  \
# 23623            DEEP   TRADITIONAL          ZONE_COVERAGE       COVER_3_ZONE
# 23624            DEEP   TRADITIONAL          ZONE_COVERAGE       COVER_3_ZONE
# 23625            DEEP   TRADITIONAL          ZONE_COVERAGE       COVER_3_ZONE
# 23626            DEEP   TRADITIONAL          ZONE_COVERAGE       COVER_3_ZONE
# 23627            DEEP   TRADITIONAL          ZONE_COVERAGE       COVER_3_ZONE
# 23628            DEEP   TRADITIONAL          ZONE_COVERAGE       COVER_3_ZONE
# 23629            DEEP   TRADITIONAL          ZONE_COVERAGE       COVER_3_ZONE
# 23630            DEEP   TRADITIONAL          ZONE_COVERAGE       COVER_3_ZONE
#
#       defender_type  potential_contact  targeted_receiver_id
# 23623          None                  0                 41233
# 23624    Converging                  0                 41233
# 23625    Converging                  0                 41233
# 23626    Converging                  0                 41233
# 23627      Trailing                  0                 41233
# 23628    Converging                  0                 41233
# 23629    Converging                  0                 41233
# 23630      Trailing                  0                 41233

# %%
local_submission = pd.read_csv('local_submission.csv')
local_submission[(local_submission['game_id'] == 2023120304) &
                    (local_submission['play_id'] == 1700)&
                    (local_submission['nfl_id'].isin([41233, 45004]))]
# train_input[(train_input['game_id'] == 2023120304)&
#                     (train_input['play_id'] == 1700)&
#                     (train_input['nfl_id'].isin([41233, 45004]))]
# Out:
#            game_id  play_id  nfl_id  frame_id     pred_x     pred_y  actual_x  \
# 380075  2023120304     1700   45004         1  66.183486  25.727335     66.20
# 380076  2023120304     1700   45004         2  65.686832  25.178041     65.71
# 380077  2023120304     1700   45004         3  65.204105  24.594663     65.23
# 380078  2023120304     1700   45004         4  64.738901  23.990867     64.78
# 380079  2023120304     1700   45004         5  64.277967  23.365867     64.31
# 380080  2023120304     1700   45004         6  63.836541  22.715394     63.86
# 380081  2023120304     1700   45004         7  63.410735  22.049510     63.42
# 380082  2023120304     1700   45004         8  62.986745  21.375515     62.96
# 380083  2023120304     1700   45004         9  62.578133  20.685969     62.52
# 380084  2023120304     1700   45004        10  62.172097  19.984677     62.06
# 380085  2023120304     1700   45004        11  61.767348  19.282300     61.59
# 380086  2023120304     1700   45004        12  61.363048  18.587412     61.14
# 380087  2023120304     1700   45004        13  60.971656  17.906429     60.69
# 380088  2023120304     1700   45004        14  60.569824  17.213724     60.24
# 380089  2023120304     1700   45004        15  60.153499  16.535549     59.80
# 380090  2023120304     1700   45004        16  59.750725  15.870584     59.40
# 380091  2023120304     1700   45004        17  59.327800  15.224785     59.04
# 380092  2023120304     1700   45004        18  58.925905  14.581370     58.71
# 380093  2023120304     1700   45004        19  58.538803  13.968805     58.40
# 380094  2023120304     1700   45004        20  58.130211  13.347998     58.14
# 380095  2023120304     1700   45004        21  57.706812  12.759677     57.91
# 380096  2023120304     1700   45004        22  57.288810  12.189241     57.71
# 380097  2023120304     1700   45004        23  56.883439  11.648636     57.54
# 380098  2023120304     1700   45004        24  56.448504  11.145473     57.39
# 380099  2023120304     1700   45004        25  56.075013  10.636093     57.26
# 380100  2023120304     1700   45004        26  55.672621  10.172781     57.14
# 380101  2023120304     1700   45004        27  55.368030   9.663773     57.03
# 380102  2023120304     1700   41233         1  72.075234  14.994376     72.09
# 380103  2023120304     1700   41233         2  71.310661  14.708882     71.36
# 380104  2023120304     1700   41233         3  70.545766  14.423315     70.61
# 380105  2023120304     1700   41233         4  69.766478  14.140351     69.84
# 380106  2023120304     1700   41233         5  68.979123  13.855773     69.07
# 380107  2023120304     1700   41233         6  68.201947  13.580816     68.29
# 380108  2023120304     1700   41233         7  67.422126  13.313373     67.49
# 380109  2023120304     1700   41233         8  66.644897  13.052660     66.69
# 380110  2023120304     1700   41233         9  65.884544  12.801621     65.89
# 380111  2023120304     1700   41233        10  65.135511  12.552753     65.08
# 380112  2023120304     1700   41233        11  64.391083  12.318567     64.29
# 380113  2023120304     1700   41233        12  63.659218  12.092398     63.53
# 380114  2023120304     1700   41233        13  62.953071  11.883498     62.78
# 380115  2023120304     1700   41233        14  62.260879  11.662516     62.06
# 380116  2023120304     1700   41233        15  61.574711  11.462298     61.36
# 380117  2023120304     1700   41233        16  60.913537  11.269456     60.71
# 380118  2023120304     1700   41233        17  60.256235  11.075875     60.09
# 380119  2023120304     1700   41233        18  59.640997  10.911793     59.53
# 380120  2023120304     1700   41233        19  59.024135  10.747938     59.02
# 380121  2023120304     1700   41233        20  58.410673  10.576419     58.56
# 380122  2023120304     1700   41233        21  57.820597  10.434826     58.16
# 380123  2023120304     1700   41233        22  57.213761  10.286623     57.80
# 380124  2023120304     1700   41233        23  56.620560  10.161755     57.49
# 380125  2023120304     1700   41233        24  56.036549  10.033790     57.32
# 380126  2023120304     1700   41233        25  55.483715   9.896708     57.15
# 380127  2023120304     1700   41233        26  54.918780   9.790596     57.03
# 380128  2023120304     1700   41233        27  54.394379   9.654358     56.94
#
#         actual_y     error
# 380075     25.68  0.050134
# 380076     25.14  0.044541
# 380077     24.55  0.051627
# 380078     23.87  0.127664
# 380079     23.16  0.208344
# 380080     22.46  0.256469
# 380081     21.74  0.309648
# 380082     21.01  0.366492
# 380083     20.29  0.400214
# 380084     19.57  0.429561
# 380085     18.86  0.458028
# 380086     18.17  0.473269
# 380087     17.50  0.494484
# 380088     16.85  0.490998
# 380089     16.22  0.473849
# 380090     15.63  0.425310
# 380091     15.07  0.326783
# 380092     14.55  0.218172
# 380093     14.06  0.166080
# 380094     13.61  0.262185
# 380095     13.16  0.448936
# 380096     12.75  0.701321
# 380097     12.38  0.982836
# 380098     12.05  1.305597
# 380099     11.75  1.626341
# 380100     11.49  1.971869
# 380101     11.26  2.304362
# 380102     15.00  0.015801
# 380103     14.71  0.049352
# 380104     14.42  0.064320
# 380105     14.13  0.074247
# 380106     13.84  0.092236
# 380107     13.55  0.093290
# 380108     13.25  0.092860
# 380109     12.96  0.103054
# 380110     12.67  0.131734
# 380111     12.39  0.171959
# 380112     12.12  0.222815
# 380113     11.86  0.265906
# 380114     11.61  0.323658
# 380115     11.39  0.338552
# 380116     11.18  0.354673
# 380117     10.99  0.345721
# 380118     10.83  0.296797
# 380119     10.70  0.239116
# 380120     10.60  0.147996
# 380121     10.52  0.159629
# 380122     10.47  0.341221
# 380123     10.44  0.605971
# 380124     10.43  0.909880
# 380125     10.43  1.343216
# 380126     10.43  1.749544
# 380127     10.43  2.205921
# 380128     10.43  2.661167

# %%
catch_probabilities = pd.read_csv('./outputs/catch_probabilities_log_flip.csv')
catch_probabilities = catch_probabilities.rename(columns={
  'pred_catch_prob_by_proj_traj': 'baseline_prob',
  'pred_catch_prob_by_real_traj': 'real_prob',
})
catch_probabilities['delta'] = catch_probabilities['real_prob'] - catch_probabilities['baseline_prob']

catch_probabilities
print(catch_probabilities.shape)
catch_probabilities = catch_probabilities.merge(supplementary_data[['game_id','play_id','pass_result', 'yards_gained', 'season','week','home_team_abbr','visitor_team_abbr','play_description', 'quarter','game_clock']],
        on=['game_id','play_id'], how='left')
print(catch_probabilities.shape)
catch_probabilities = catch_probabilities.merge(train_input_pre[['game_id','play_id','passer_nfl_id','num_output_frames', 'num_output_frames_bin']].drop_duplicates(),
        on=['game_id','play_id'], how='left')
print(catch_probabilities.shape)
catch_probabilities = catch_probabilities.merge(suppl_data_pre,
        on=['game_id','play_id'], how='left')
print(catch_probabilities.shape)
catch_probabilities.sort_values('delta', ascending = False).head(3)
# Out:
# (14108, 5)
# (14108, 14)
# (14108, 17)
# (14108, 28)
#           game_id  play_id  baseline_prob  real_prob     delta pass_result  \
# 3471   2023100805     2735       0.093919   0.741877  0.647958           C
# 11755  2023091711     1082       0.123415   0.744086  0.620671           C
# 12691  2023110200     2677       0.215321   0.819346  0.604025           I
#
#        yards_gained  season  week home_team_abbr visitor_team_abbr  \
# 3471              3    2023     5             NE                NO
# 11755            53    2023     2            DEN               WAS
# 12691             0    2023     9            PIT               TEN
#
#                                         play_description  quarter game_clock  \
# 3471   (9:12) (Shotgun) D.Carr pass short right to R....        3      09:12
# 11755  (13:15) (Shotgun) R.Wilson pass deep left to M...        2      13:15
# 12691  (5:49) (Shotgun) K.Pickett pass incomplete sho...        3      05:49
#
#        passer_nfl_id  num_output_frames num_output_frames_bin possession_team  \
# 3471         41265.0                 14                MEDIUM              NO
# 11755        38605.0                 27                  LONG             DEN
# 12691        54485.0                 19                MEDIUM             PIT
#
#       defensive_team down_and_distance receiver_alignment  \
# 3471              NE        2nd_medium                3x1
# 11755            WAS        3rd_medium                2x2
# 12691            TEN         3rd_short                3x1
#
#       route_of_targeted_receiver route_type_of_targeted_receiver  pass_length  \
# 3471                       HITCH                      STOP_HITCH            3
# 11755                         GO                        VERTICAL           45
# 12691                         GO                        VERTICAL           12
#
#       pass_length_bin dropback_type team_coverage_man_zone team_coverage_type
# 3471            SHORT   TRADITIONAL          ZONE_COVERAGE       COVER_3_ZONE
# 11755            DEEP   TRADITIONAL           MAN_COVERAGE        COVER_1_MAN
# 12691    INTERMEDIATE   TRADITIONAL           MAN_COVERAGE        COVER_1_MAN

# %%
# 2023120304	1700	
catch_probabilities[(catch_probabilities['game_id'] == 2023120304)&
                    (catch_probabilities['play_id'] == 1700)]
# Out:
#          game_id  play_id  baseline_prob  real_prob     delta pass_result  \
# 7244  2023120304     1700       0.104038   0.190962  0.086924          IN
#
#       yards_gained  season  week home_team_abbr visitor_team_abbr  \
# 7244             0    2023    13             TB               CAR
#
#                                        play_description  quarter game_clock  \
# 7244  (2:31) (Shotgun) B.Mayfield pass deep left int...        2      02:31
#
#       passer_nfl_id  num_output_frames num_output_frames_bin possession_team  \
# 7244        46070.0                 27                  LONG              TB
#
#      defensive_team down_and_distance receiver_alignment  \
# 7244            CAR         3rd_short                3x1
#
#      route_of_targeted_receiver route_type_of_targeted_receiver  pass_length  \
# 7244                         GO                        VERTICAL           28
#
#      pass_length_bin dropback_type team_coverage_man_zone team_coverage_type
# 7244            DEEP   TRADITIONAL          ZONE_COVERAGE       COVER_3_ZONE

# %%
min_plays = 30
player_stats = (player_impacts[player_impacts['player_role'] == 'Targeted Receiver']
    .groupby('nfl_id').agg(
      mean_delta=('delta', 'mean'),
      std_delta=('delta', 'std'),
      n_plays=('delta', 'count')
).query(f'n_plays >= {min_plays}')
)

# %%
# Variance between players (signal)
var_between = player_stats['mean_delta'].var()

# Average variance within players (noise)
var_within = (player_stats['std_delta'] ** 2).mean()

# ICC
icc = var_between / (var_between + var_within)
print(f"ICC for WR delta: {icc:.3f}")
# Out:
# ICC for WR delta: 0.025

# %%
from typing import Union, List, Dict, Callable

def apply_filter_dict(
    df: pd.DataFrame, 
    filter_dict: Dict[str, Union[str, List, Callable]]
) -> pd.DataFrame:
    filtered_df = df.copy()
    
    for col, condition in filter_dict.items():
        if callable(condition):
            # Lambda/function filter
            filtered_df = filtered_df[filtered_df[col].apply(condition)]
        elif isinstance(condition, list):
            # List of values (OR condition)
            filtered_df = filtered_df[filtered_df[col].isin(condition)]
        else:
            # Single value equality
            filtered_df = filtered_df[filtered_df[col] == condition]
    
    return filtered_df


def assess_icc_by_cut(
    df: pd.DataFrame, 
    min_plays: int,
    filter_dict: Dict[str, Union[str, List, Callable]] = None,
    groupby_cols: Union[str, List[str]] = 'nfl_id',
    label: str = 'default'
) -> Dict[str, float]:
    """
    Assess ICC with flexible filtering and grouping.
    
    Args:
        df: Input dataframe (player_impacts)
        min_plays: Minimum plays threshold
        filter_dict: Dictionary of {column: value/list/callable}
            Examples:
                {'player_role': 'Targeted Receiver'}
                {'player_role': ['Targeted Receiver', 'Defensive Coverage']}
                {'yards_gained': lambda x: x > 10}
        groupby_cols: Column(s) to group by. Can be string or list of strings
            Examples: 'nfl_id', ['nfl_id', 'quarter'], ['game_id', 'play_id']
    
    Returns:
        Dictionary with ICC metrics and metadata
    """
    filtered_df = df.copy()
    
    if filter_dict:
        filtered_df = apply_filter_dict(filtered_df, filter_dict)
    
    if isinstance(groupby_cols, str):
        groupby_cols = [groupby_cols]
    
    player_stats = (
        filtered_df
        .groupby(groupby_cols)
        .agg(
            mean_delta=('delta', 'mean'),
            std_delta=('delta', 'std'),
            n_plays=('delta', 'count')
        )
        .query(f'n_plays >= {min_plays}')
    )
    
    # Handle case where no groups survive
    if len(player_stats) == 0:
        return
    
    var_between = player_stats['mean_delta'].var()
    var_within = (player_stats['std_delta'] ** 2).mean()
    icc = var_between / (var_between + var_within) if (var_between + var_within) > 0 else np.nan
    
    return {
        'label': label,
        'icc': icc,
        'var_between': var_between,
        'var_within': var_within,
        'n_groups': len(player_stats),
        'groupby': groupby_cols,
        'filters': filter_dict,
    }

# %%
supplementary_data['team_coverage_man_zone'].value_counts()
# Out:
# team_coverage_man_zone
# ZONE_COVERAGE    12783
# MAN_COVERAGE      5221
# Name: count, dtype: int64

# %%
# ======================
# Variation By Team - Unfiltered
# ======================

print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      # filter_dict={'player_role': ['Targeted Receiver', 'Defensive Coverage']},
      groupby_cols='defensive_team',
      label = 'Variation by Defensive Team'
  )
)

print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      # filter_dict={'player_role': 'Defensive Coverage'},
      groupby_cols='possession_team',
      label = 'Variation by Offensive Team'
  )
)
# Out:
# {'label': 'Variation by Defensive Team', 'icc': np.float64(0.0024441665827069545), 'var_between': np.float64(2.3870740334407182e-05), 'var_within': np.float64(0.00974254227885103), 'n_groups': 32, 'groupby': ['defensive_team'], 'filters': None}
# {'label': 'Variation by Offensive Team', 'icc': np.float64(0.006384084965308083), 'var_between': np.float64(6.222867556966294e-05), 'var_within': np.float64(0.009685241151010238), 'n_groups': 32, 'groupby': ['possession_team'], 'filters': None}

# %%
# ======================
# Variation by Defensive Team
# ======================
print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      # filter_dict={'player_role': ['Targeted Receiver', 'Defensive Coverage']},
      groupby_cols='defensive_team',
      label = 'Variation by Defensive Team'
  )
)

print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      filter_dict={'down_and_distance': "3rd_long"},
      groupby_cols='defensive_team',
      label = 'Variation by Defensive Team - On 3rd and Long'
  )
)

print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      filter_dict={'route_type_of_targeted_receiver': "VERTICAL"},
      groupby_cols='defensive_team',
      label = 'Variation by Defensive Team - On Vertical Routes'
  )
)

print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      filter_dict={'route_type_of_targeted_receiver': "OUT_BREAK"},
      groupby_cols='defensive_team',
      label = 'Variation by Defensive Team - On Out Breaking Routes'
  )
)

print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      filter_dict={'route_type_of_targeted_receiver': "IN_BREAK"},
      groupby_cols='defensive_team',
      label = 'Variation by Defensive Team - On In Breaking Routes'
  )
)

print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      filter_dict={'pass_length_bin': "SHORT"},
      groupby_cols='defensive_team',
      label = 'Variation by Defensive Team - On Short Pass Lengths'
  )
)

print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      filter_dict={'pass_length_bin': "INTERMEDIATE"},
      groupby_cols='defensive_team',
      label = 'Variation by Defensive Team - On Intermediate Pass Lengths'
  )
)

print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      filter_dict={'pass_length_bin': "DEEP"},
      groupby_cols='defensive_team',
      label = 'Variation by Defensive Team - On Deep Pass Lengths'
  )
)


print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      filter_dict={'num_output_frames_bin': "QUICK"},
      groupby_cols='defensive_team',
      label = 'Variation by Defensive Team - On Quick Passes'
  )
)

print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      filter_dict={'num_output_frames_bin': "MEDIUM"},
      groupby_cols='defensive_team',
      label = 'Variation by Defensive Team - On Medium-Time Passes'
  )
)

print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      filter_dict={'num_output_frames_bin': "LONG"},
      groupby_cols='defensive_team',
      label = 'Variation by Defensive Team - On Long-Time Passes'
  )
)

print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      filter_dict={'team_coverage_man_zone': "ZONE_COVERAGE"},
      groupby_cols='defensive_team',
      label = 'Variation by Defensive Team - Playing Zone'
  )
)

print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      filter_dict={'team_coverage_man_zone': "MAN_COVERAGE"},
      groupby_cols='defensive_team',
      label = 'Variation by Defensive Team - Playing Man'
  )
)
# Out:
# {'label': 'Variation by Defensive Team', 'icc': np.float64(0.0024441665827069545), 'var_between': np.float64(2.3870740334407182e-05), 'var_within': np.float64(0.00974254227885103), 'n_groups': 32, 'groupby': ['defensive_team'], 'filters': None}
# {'label': 'Variation by Defensive Team - On 3rd and Long', 'icc': np.float64(0.021007752004882686), 'var_between': np.float64(0.00024008474744227217), 'var_within': np.float64(0.011188303563047633), 'n_groups': 32, 'groupby': ['defensive_team'], 'filters': {'down_and_distance': '3rd_long'}}
# {'label': 'Variation by Defensive Team - On Vertical Routes', 'icc': np.float64(0.014976087959534212), 'var_between': np.float64(0.0002896495692529152), 'var_within': np.float64(0.019051153585453177), 'n_groups': 32, 'groupby': ['defensive_team'], 'filters': {'route_type_of_targeted_receiver': 'VERTICAL'}}
# {'label': 'Variation by Defensive Team - On Out Breaking Routes', 'icc': np.float64(0.0060740782368218825), 'var_between': np.float64(4.014316867018345e-05), 'var_within': np.float64(0.006568788607484779), 'n_groups': 32, 'groupby': ['defensive_team'], 'filters': {'route_type_of_targeted_receiver': 'OUT_BREAK'}}
# {'label': 'Variation by Defensive Team - On In Breaking Routes', 'icc': np.float64(0.006862149607126987), 'var_between': np.float64(5.41381777041938e-05), 'var_within': np.float64(0.007835252290840271), 'n_groups': 32, 'groupby': ['defensive_team'], 'filters': {'route_type_of_targeted_receiver': 'IN_BREAK'}}
# {'label': 'Variation by Defensive Team - On Short Pass Lengths', 'icc': np.float64(0.003098293885848324), 'var_between': np.float64(2.0158616745201766e-05), 'var_within': np.float64(0.0064862018151291495), 'n_groups': 32, 'groupby': ['defensive_team'], 'filters': {'pass_length_bin': 'SHORT'}}
# {'label': 'Variation by Defensive Team - On Intermediate Pass Lengths', 'icc': np.float64(0.010542579264028204), 'var_between': np.float64(0.00015964405693015606), 'var_within': np.float64(0.014983145286363605), 'n_groups': 32, 'groupby': ['defensive_team'], 'filters': {'pass_length_bin': 'INTERMEDIATE'}}
# {'label': 'Variation by Defensive Team - On Deep Pass Lengths', 'icc': np.float64(0.015937585254788937), 'var_between': np.float64(0.0003076410635295645), 'var_within': np.float64(0.018995224371315674), 'n_groups': 32, 'groupby': ['defensive_team'], 'filters': {'pass_length_bin': 'DEEP'}}
# {'label': 'Variation by Defensive Team - On Quick Passes', 'icc': np.float64(0.003598165488889784), 'var_between': np.float64(1.9955395178596743e-05), 'var_within': np.float64(0.005526036094155039), 'n_groups': 32, 'groupby': ['defensive_team'], 'filters': {'num_output_frames_bin': 'QUICK'}}
# {'label': 'Variation by Defensive Team - On Medium-Time Passes', 'icc': np.float64(0.006336218443463734), 'var_between': np.float64(9.20473579147748e-05), 'var_within': np.float64(0.014435128233660399), 'n_groups': 32, 'groupby': ['defensive_team'], 'filters': {'num_output_frames_bin': 'MEDIUM'}}
# {'label': 'Variation by Defensive Team - On Long-Time Passes', 'icc': np.float64(0.028497844197708934), 'var_between': np.float64(0.0005898295809800214), 'var_within': np.float64(0.02010751078231105), 'n_groups': 31, 'groupby': ['defensive_team'], 'filters': {'num_output_frames_bin': 'LONG'}}
# {'label': 'Variation by Defensive Team - Playing Zone', 'icc': np.float64(0.004125285642777219), 'var_between': np.float64(3.541742102811474e-05), 'var_within': np.float64(0.008550029526173116), 'n_groups': 32, 'groupby': ['defensive_team'], 'filters': {'team_coverage_man_zone': 'ZONE_COVERAGE'}}
# {'label': 'Variation by Defensive Team - Playing Man', 'icc': np.float64(0.010173505920646054), 'var_between': np.float64(0.00012984892098488065), 'var_within': np.float64(0.012633589956203563), 'n_groups': 32, 'groupby': ['defensive_team'], 'filters': {'team_coverage_man_zone': 'MAN_COVERAGE'}}

# %%
# ======================
# Variation by Offensive Team
# ======================
print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      # filter_dict={'player_role': ['Targeted Receiver', 'Defensive Coverage']},
      groupby_cols='possession_team',
      label = 'Variation by Offensive Team'
  )
)

print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      filter_dict={'down_and_distance': "3rd_long"},
      groupby_cols='possession_team',
      label = 'Variation by Offensive Team - On 3rd and Long'
  )
)

print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      filter_dict={'route_type_of_targeted_receiver': "VERTICAL"},
      groupby_cols='possession_team',
      label = 'Variation by Offensive Team - On Vertical Routes'
  )
)

print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      filter_dict={'route_type_of_targeted_receiver': "OUT_BREAK"},
      groupby_cols='possession_team',
      label = 'Variation by Offensive Team - On Out Breaking Routes'
  )
)

print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      filter_dict={'route_type_of_targeted_receiver': "IN_BREAK"},
      groupby_cols='possession_team',
      label = 'Variation by Offensive Team - On In Breaking Routes'
  )
)

print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      filter_dict={'pass_length_bin': "SHORT"},
      groupby_cols='possession_team',
      label = 'Variation by Offensive Team - On Short Pass Lengths'
  )
)

print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      filter_dict={'pass_length_bin': "INTERMEDIATE"},
      groupby_cols='possession_team',
      label = 'Variation by Offensive Team - On Intermediate Pass Lengths'
  )
)

print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      filter_dict={'pass_length_bin': "DEEP"},
      groupby_cols='possession_team',
      label = 'Variation by Offensive Team - On Deep Pass Lengths'
  )
)


print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      filter_dict={'num_output_frames_bin': "QUICK"},
      groupby_cols='possession_team',
      label = 'Variation by Offensive Team - On Quick Passes'
  )
)

print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      filter_dict={'num_output_frames_bin': "MEDIUM"},
      groupby_cols='possession_team',
      label = 'Variation by Offensive Team - On Medium-Time Passes'
  )
)

print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      filter_dict={'num_output_frames_bin': "LONG"},
      groupby_cols='possession_team',
      label = 'Variation by Offensive Team - On Long-Time Passes'
  )
)


print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      filter_dict={'team_coverage_man_zone': "MAN_COVERAGE"},
      groupby_cols='possession_team',
      label = 'Variation by Offensive Team - Playing Man'
  )
)
print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      filter_dict={'team_coverage_man_zone': "ZONE_COVERAGE"},
      groupby_cols='possession_team',
      label = 'Variation by Offensive Team - Playing Zone'
  )
)
# Out:
# {'label': 'Variation by Offensive Team', 'icc': np.float64(0.006384084965308083), 'var_between': np.float64(6.222867556966294e-05), 'var_within': np.float64(0.009685241151010238), 'n_groups': 32, 'groupby': ['possession_team'], 'filters': None}
# {'label': 'Variation by Offensive Team - On 3rd and Long', 'icc': np.float64(0.024899291587198582), 'var_between': np.float64(0.00028549918125521725), 'var_within': np.float64(0.011180657606996554), 'n_groups': 32, 'groupby': ['possession_team'], 'filters': {'down_and_distance': '3rd_long'}}
# {'label': 'Variation by Offensive Team - On Vertical Routes', 'icc': np.float64(0.018008561640585664), 'var_between': np.float64(0.0003506421957167968), 'var_within': np.float64(0.019120218537911092), 'n_groups': 32, 'groupby': ['possession_team'], 'filters': {'route_type_of_targeted_receiver': 'VERTICAL'}}
# {'label': 'Variation by Offensive Team - On Out Breaking Routes', 'icc': np.float64(0.011494683916281851), 'var_between': np.float64(7.669383025247356e-05), 'var_within': np.float64(0.006595419192693656), 'n_groups': 32, 'groupby': ['possession_team'], 'filters': {'route_type_of_targeted_receiver': 'OUT_BREAK'}}
# {'label': 'Variation by Offensive Team - On In Breaking Routes', 'icc': np.float64(0.012427773196106233), 'var_between': np.float64(9.618009796064601e-05), 'var_within': np.float64(0.007642945523577117), 'n_groups': 32, 'groupby': ['possession_team'], 'filters': {'route_type_of_targeted_receiver': 'IN_BREAK'}}
# {'label': 'Variation by Offensive Team - On Short Pass Lengths', 'icc': np.float64(0.008470331694435871), 'var_between': np.float64(5.4844187396640284e-05), 'var_within': np.float64(0.0064200129227053445), 'n_groups': 32, 'groupby': ['possession_team'], 'filters': {'pass_length_bin': 'SHORT'}}
# {'label': 'Variation by Offensive Team - On Intermediate Pass Lengths', 'icc': np.float64(0.011498772290170033), 'var_between': np.float64(0.00017306759953115975), 'var_within': np.float64(0.014877895682793355), 'n_groups': 32, 'groupby': ['possession_team'], 'filters': {'pass_length_bin': 'INTERMEDIATE'}}
# {'label': 'Variation by Offensive Team - On Deep Pass Lengths', 'icc': np.float64(0.02650239727167323), 'var_between': np.float64(0.000516591374457287), 'var_within': np.float64(0.018975659426923593), 'n_groups': 32, 'groupby': ['possession_team'], 'filters': {'pass_length_bin': 'DEEP'}}
# {'label': 'Variation by Offensive Team - On Quick Passes', 'icc': np.float64(0.007432754627729516), 'var_between': np.float64(4.1261705867578326e-05), 'var_within': np.float64(0.005510072615548403), 'n_groups': 32, 'groupby': ['possession_team'], 'filters': {'num_output_frames_bin': 'QUICK'}}
# {'label': 'Variation by Offensive Team - On Medium-Time Passes', 'icc': np.float64(0.010677301559258697), 'var_between': np.float64(0.00015453444939042237), 'var_within': np.float64(0.014318640119367508), 'n_groups': 32, 'groupby': ['possession_team'], 'filters': {'num_output_frames_bin': 'MEDIUM'}}
# {'label': 'Variation by Offensive Team - On Long-Time Passes', 'icc': np.float64(0.050463549246552164), 'var_between': np.float64(0.001004475181285822), 'var_within': np.float64(0.01890048981390724), 'n_groups': 30, 'groupby': ['possession_team'], 'filters': {'num_output_frames_bin': 'LONG'}}
# {'label': 'Variation by Offensive Team - Playing Man', 'icc': np.float64(0.010581373347900913), 'var_between': np.float64(0.00013710115511119474), 'var_within': np.float64(0.012819738245928584), 'n_groups': 32, 'groupby': ['possession_team'], 'filters': {'team_coverage_man_zone': 'MAN_COVERAGE'}}
# {'label': 'Variation by Offensive Team - Playing Zone', 'icc': np.float64(0.008056370816214459), 'var_between': np.float64(6.885731856544645e-05), 'var_within': np.float64(0.008478082753614752), 'n_groups': 32, 'groupby': ['possession_team'], 'filters': {'team_coverage_man_zone': 'ZONE_COVERAGE'}}

# %%
# ======================
# Variation by Passer
# ======================
print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      # filter_dict={'player_role': ['Targeted Receiver', 'Defensive Coverage']},
      groupby_cols='passer_nfl_id',
      label = 'Variation by Passer'
  )
)

print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      filter_dict={'down_and_distance': "3rd_long"},
      groupby_cols='passer_nfl_id',
      label = 'Variation by Passer - On 3rd and Long'
  )
)

print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      filter_dict={'route_type_of_targeted_receiver': "VERTICAL"},
      groupby_cols='passer_nfl_id',
      label = 'Variation by Passer - On Vertical Routes'
  )
)

print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      filter_dict={'route_type_of_targeted_receiver': "OUT_BREAK"},
      groupby_cols='passer_nfl_id',
      label = 'Variation by Passer - On Out Breaking Routes'
  )
)

print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      filter_dict={'route_type_of_targeted_receiver': "IN_BREAK"},
      groupby_cols='passer_nfl_id',
      label = 'Variation by Passer - On In Breaking Routes'
  )
)

print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      filter_dict={'pass_length_bin': "SHORT"},
      groupby_cols='passer_nfl_id',
      label = 'Variation by Passer - On Short Pass Lengths'
  )
)

print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      filter_dict={'pass_length_bin': "INTERMEDIATE"},
      groupby_cols='passer_nfl_id',
      label = 'Variation by Passer - On Intermediate Pass Lengths'
  )
)

print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      filter_dict={'pass_length_bin': "DEEP"},
      groupby_cols='passer_nfl_id',
      label = 'Variation by Passer - On Deep Pass Lengths'
  )
)


print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      filter_dict={'num_output_frames_bin': "QUICK"},
      groupby_cols='passer_nfl_id',
      label = 'Variation by Passer - On Quick Passes'
  )
)

print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      filter_dict={'num_output_frames_bin': "MEDIUM"},
      groupby_cols='passer_nfl_id',
      label = 'Variation by Passer - On Medium-Time Passes'
  )
)

print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      filter_dict={'num_output_frames_bin': "LONG"},
      groupby_cols='passer_nfl_id',
      label = 'Variation by Passer - On Long-Time Passes'
  )
)


print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      filter_dict={'team_coverage_man_zone': "MAN_COVERAGE"},
      groupby_cols='passer_nfl_id',
      label = 'Variation by Passer - Playing Man'
  )
)
print(
  assess_icc_by_cut(
      catch_probabilities,
      min_plays=20,
      filter_dict={'team_coverage_man_zone': "ZONE_COVERAGE"},
      groupby_cols='passer_nfl_id',
      label = 'Variation by Passer - Playing Zone'
  )
)
# Out:
# {'label': 'Variation by Passer', 'icc': np.float64(0.019864380528396265), 'var_between': np.float64(0.00019785043245144806), 'var_within': np.float64(0.00976221009743115), 'n_groups': 66, 'groupby': ['passer_nfl_id'], 'filters': None}
# {'label': 'Variation by Passer - On 3rd and Long', 'icc': np.float64(0.05249238594811048), 'var_between': np.float64(0.0006159101257676928), 'var_within': np.float64(0.011117412996113818), 'n_groups': 35, 'groupby': ['passer_nfl_id'], 'filters': {'down_and_distance': '3rd_long'}}
# {'label': 'Variation by Passer - On Vertical Routes', 'icc': np.float64(0.025337759141313976), 'var_between': np.float64(0.0005026945003795428), 'var_within': np.float64(0.019337043401299554), 'n_groups': 42, 'groupby': ['passer_nfl_id'], 'filters': {'route_type_of_targeted_receiver': 'VERTICAL'}}
# {'label': 'Variation by Passer - On Out Breaking Routes', 'icc': np.float64(0.019809287357455584), 'var_between': np.float64(0.00013491319236826516), 'var_within': np.float64(0.006675689831040759), 'n_groups': 51, 'groupby': ['passer_nfl_id'], 'filters': {'route_type_of_targeted_receiver': 'OUT_BREAK'}}
# {'label': 'Variation by Passer - On In Breaking Routes', 'icc': np.float64(0.025497933405908974), 'var_between': np.float64(0.00019900064782271289), 'var_within': np.float64(0.007605578831414449), 'n_groups': 49, 'groupby': ['passer_nfl_id'], 'filters': {'route_type_of_targeted_receiver': 'IN_BREAK'}}
# {'label': 'Variation by Passer - On Short Pass Lengths', 'icc': np.float64(0.02540795142380975), 'var_between': np.float64(0.0001704232983673571), 'var_within': np.float64(0.0065370556134371465), 'n_groups': 60, 'groupby': ['passer_nfl_id'], 'filters': {'pass_length_bin': 'SHORT'}}
# {'label': 'Variation by Passer - On Intermediate Pass Lengths', 'icc': np.float64(0.031077376236030994), 'var_between': np.float64(0.00046973290985293664), 'var_within': np.float64(0.01464521457751989), 'n_groups': 43, 'groupby': ['passer_nfl_id'], 'filters': {'pass_length_bin': 'INTERMEDIATE'}}
# {'label': 'Variation by Passer - On Deep Pass Lengths', 'icc': np.float64(0.023944427403769262), 'var_between': np.float64(0.0004779788138827496), 'var_within': np.float64(0.019484027619710544), 'n_groups': 34, 'groupby': ['passer_nfl_id'], 'filters': {'pass_length_bin': 'DEEP'}}
# {'label': 'Variation by Passer - On Quick Passes', 'icc': np.float64(0.01625083467857424), 'var_between': np.float64(9.00545333728839e-05), 'var_within': np.float64(0.005451478265038723), 'n_groups': 58, 'groupby': ['passer_nfl_id'], 'filters': {'num_output_frames_bin': 'QUICK'}}
# {'label': 'Variation by Passer - On Medium-Time Passes', 'icc': np.float64(0.02664460254097735), 'var_between': np.float64(0.00038641654280432893), 'var_within': np.float64(0.014116203348411913), 'n_groups': 48, 'groupby': ['passer_nfl_id'], 'filters': {'num_output_frames_bin': 'MEDIUM'}}
# {'label': 'Variation by Passer - On Long-Time Passes', 'icc': np.float64(0.05733462738888501), 'var_between': np.float64(0.0011784858757503227), 'var_within': np.float64(0.019376036398493775), 'n_groups': 22, 'groupby': ['passer_nfl_id'], 'filters': {'num_output_frames_bin': 'LONG'}}
# {'label': 'Variation by Passer - Playing Man', 'icc': np.float64(0.0203076646009775), 'var_between': np.float64(0.0002665685681166944), 'var_within': np.float64(0.01285993186186693), 'n_groups': 44, 'groupby': ['passer_nfl_id'], 'filters': {'team_coverage_man_zone': 'MAN_COVERAGE'}}
# {'label': 'Variation by Passer - Playing Zone', 'icc': np.float64(0.023224232346616195), 'var_between': np.float64(0.000196125638125573), 'var_within': np.float64(0.00824874501242787), 'n_groups': 62, 'groupby': ['passer_nfl_id'], 'filters': {'team_coverage_man_zone': 'ZONE_COVERAGE'}}

# %%
# ======================
# Variation by Receiver (All Roles)
# ======================

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=15,
      filter_dict={'player_role': 'Targeted Receiver'},
      groupby_cols='nfl_id',
      label = 'Variation by Receiver ID - All'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_role": 'Targeted Receiver',
        'route_type_of_targeted_receiver': "VERTICAL"},
      groupby_cols='nfl_id',
      label = 'Variation by Receiver ID - On Vertical Routes'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_role": 'Targeted Receiver',
        'route_type_of_targeted_receiver': "OUT_BREAK"},
      groupby_cols='nfl_id',
      label = 'Variation by Receiver ID - On Out Breaking Routes'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_role": 'Targeted Receiver',
        'route_type_of_targeted_receiver': "IN_BREAK"},
      groupby_cols='nfl_id',
      label = 'Variation by Receiver ID - On In Breaking Routes'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_role": 'Targeted Receiver',
        'pass_length_bin': "SHORT"},
      groupby_cols='nfl_id',
      label = 'Variation by Receiver ID - On Short Pass Lengths'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_role": 'Targeted Receiver',
        'pass_length_bin': "INTERMEDIATE"},
      groupby_cols='nfl_id',
      label = 'Variation by Receiver ID - On Intermediate Pass Lengths'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_role": 'Targeted Receiver',
        'pass_length_bin': "DEEP"},
      groupby_cols='nfl_id',
      label = 'Variation by Receiver ID - On Deep Pass Lengths'
  )
)


print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_role": 'Targeted Receiver',
        'num_output_frames_bin': "QUICK"},
      groupby_cols='nfl_id',
      label = 'Variation by Receiver ID - On Quick Passes'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_role": 'Targeted Receiver',
        'num_output_frames_bin': "MEDIUM"},
      groupby_cols='nfl_id',
      label = 'Variation by Receiver ID - On Medium-Time Passes'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_role": 'Targeted Receiver',
        'num_output_frames_bin': "LONG"},
      groupby_cols='nfl_id',
      label = 'Variation by Receiver ID - On Long-Time Passes'
  )
)


print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_role": 'Targeted Receiver',
        'team_coverage_man_zone': "MAN_COVERAGE"},
      groupby_cols='nfl_id',
      label = 'Variation by Receiver ID - Playing Man'
  )
)
print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_role": 'Targeted Receiver',
        'team_coverage_man_zone': "ZONE_COVERAGE"},
      groupby_cols='nfl_id',
      label = 'Variation by Receiver ID - Playing Zone'
  )
)
# Out:
# {'label': 'Variation by Receiver ID - All', 'icc': np.float64(0.03514725613592786), 'var_between': np.float64(0.00030345148822727723), 'var_within': np.float64(0.008330266235105504), 'n_groups': 261, 'groupby': ['nfl_id'], 'filters': {'player_role': 'Targeted Receiver'}}
# {'label': 'Variation by Receiver ID - On Vertical Routes', 'icc': np.float64(0.02627690121256957), 'var_between': np.float64(0.0005133479785909124), 'var_within': np.float64(0.01902274474551432), 'n_groups': 41, 'groupby': ['nfl_id'], 'filters': {'player_role': 'Targeted Receiver', 'route_type_of_targeted_receiver': 'VERTICAL'}}
# {'label': 'Variation by Receiver ID - On Out Breaking Routes', 'icc': np.float64(0.0439197206073641), 'var_between': np.float64(0.0002916633775335535), 'var_within': np.float64(0.006349166151893139), 'n_groups': 65, 'groupby': ['nfl_id'], 'filters': {'player_role': 'Targeted Receiver', 'route_type_of_targeted_receiver': 'OUT_BREAK'}}
# {'label': 'Variation by Receiver ID - On In Breaking Routes', 'icc': np.float64(0.057859622940398286), 'var_between': np.float64(0.0004781225128204464), 'var_within': np.float64(0.007785369167949141), 'n_groups': 66, 'groupby': ['nfl_id'], 'filters': {'player_role': 'Targeted Receiver', 'route_type_of_targeted_receiver': 'IN_BREAK'}}
# {'label': 'Variation by Receiver ID - On Short Pass Lengths', 'icc': np.float64(0.03455234280491803), 'var_between': np.float64(0.00021896722303554607), 'var_within': np.float64(0.00611829402352685), 'n_groups': 181, 'groupby': ['nfl_id'], 'filters': {'player_role': 'Targeted Receiver', 'pass_length_bin': 'SHORT'}}
# {'label': 'Variation by Receiver ID - On Intermediate Pass Lengths', 'icc': np.float64(0.05125890421390194), 'var_between': np.float64(0.0007552077078693324), 'var_within': np.float64(0.013977992688258379), 'n_groups': 50, 'groupby': ['nfl_id'], 'filters': {'player_role': 'Targeted Receiver', 'pass_length_bin': 'INTERMEDIATE'}}
# {'label': 'Variation by Receiver ID - On Deep Pass Lengths', 'icc': np.float64(0.03992849938127667), 'var_between': np.float64(0.0007687063568680785), 'var_within': np.float64(0.018483365941860518), 'n_groups': 12, 'groupby': ['nfl_id'], 'filters': {'player_role': 'Targeted Receiver', 'pass_length_bin': 'DEEP'}}
# {'label': 'Variation by Receiver ID - On Quick Passes', 'icc': np.float64(0.042580469888564114), 'var_between': np.float64(0.0002328964007552478), 'var_within': np.float64(0.005236662797740048), 'n_groups': 161, 'groupby': ['nfl_id'], 'filters': {'player_role': 'Targeted Receiver', 'num_output_frames_bin': 'QUICK'}}
# {'label': 'Variation by Receiver ID - On Medium-Time Passes', 'icc': np.float64(0.047122253195416436), 'var_between': np.float64(0.0006825846117991732), 'var_within': np.float64(0.013802813804284376), 'n_groups': 84, 'groupby': ['nfl_id'], 'filters': {'player_role': 'Targeted Receiver', 'num_output_frames_bin': 'MEDIUM'}}
# {'label': 'Variation by Receiver ID - On Long-Time Passes', 'icc': np.float64(0.06319003943524143), 'var_between': np.float64(0.0011865881087517488), 'var_within': np.float64(0.017591499693642976), 'n_groups': 3, 'groupby': ['nfl_id'], 'filters': {'player_role': 'Targeted Receiver', 'num_output_frames_bin': 'LONG'}}
# {'label': 'Variation by Receiver ID - Playing Man', 'icc': np.float64(0.04693486618241378), 'var_between': np.float64(0.0006507338253274934), 'var_within': np.float64(0.013213880655480799), 'n_groups': 75, 'groupby': ['nfl_id'], 'filters': {'player_role': 'Targeted Receiver', 'team_coverage_man_zone': 'MAN_COVERAGE'}}
# {'label': 'Variation by Receiver ID - Playing Zone', 'icc': np.float64(0.03578868852624505), 'var_between': np.float64(0.00028821621352771265), 'var_within': np.float64(0.007765060545031184), 'n_groups': 184, 'groupby': ['nfl_id'], 'filters': {'player_role': 'Targeted Receiver', 'team_coverage_man_zone': 'ZONE_COVERAGE'}}

# %%
# ======================
# Variation by Defender (All Roles)
# ======================

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={'player_role': 'Defensive Coverage'},
      groupby_cols='nfl_id',
      label = 'Variation by Defender ID - All'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_role": 'Defensive Coverage',
        'route_type_of_targeted_receiver': "VERTICAL"},
      groupby_cols='nfl_id',
      label = 'Variation by Defender ID - On Vertical Routes'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_role": 'Defensive Coverage',
        'route_type_of_targeted_receiver': "OUT_BREAK"},
      groupby_cols='nfl_id',
      label = 'Variation by Defender ID - On Out Breaking Routes'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_role": 'Defensive Coverage',
        'route_type_of_targeted_receiver': "IN_BREAK"},
      groupby_cols='nfl_id',
      label = 'Variation by Defender ID - On In Breaking Routes'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_role": 'Defensive Coverage',
        'pass_length_bin': "SHORT"},
      groupby_cols='nfl_id',
      label = 'Variation by Defender ID - On Short Pass Lengths'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_role": 'Defensive Coverage',
        'pass_length_bin': "INTERMEDIATE"},
      groupby_cols='nfl_id',
      label = 'Variation by Defender ID - On Intermediate Pass Lengths'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_role": 'Defensive Coverage',
        'pass_length_bin': "DEEP"},
      groupby_cols='nfl_id',
      label = 'Variation by Defender ID - On Deep Pass Lengths'
  )
)


print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_role": 'Defensive Coverage',
        'num_output_frames_bin': "QUICK"},
      groupby_cols='nfl_id',
      label = 'Variation by Defender ID - On Quick Passes'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_role": 'Defensive Coverage',
        'num_output_frames_bin': "MEDIUM"},
      groupby_cols='nfl_id',
      label = 'Variation by Defender ID - On Medium-Time Passes'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_role": 'Defensive Coverage',
        'num_output_frames_bin': "LONG"},
      groupby_cols='nfl_id',
      label = 'Variation by Defender ID - On Long-Time Passes'
  )
)


print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_role": 'Defensive Coverage',
        'team_coverage_man_zone': "MAN_COVERAGE"},
      groupby_cols='nfl_id',
      label = 'Variation by Defender ID - Playing Man'
  )
)
print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_role": 'Defensive Coverage',
        'team_coverage_man_zone': "ZONE_COVERAGE"},
      groupby_cols='nfl_id',
      label = 'Variation by Defender ID - Playing Zone'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_role": 'Defensive Coverage',
        # 'team_coverage_man_zone': "ZONE_COVERAGE",
        "defender_type": "Converging"},
      groupby_cols='nfl_id',
      label = 'Variation by Defender ID - When Converging'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_role": 'Defensive Coverage',
        # 'team_coverage_man_zone': "ZONE_COVERAGE",
        "defender_type": "Converging",
        'pass_length_bin': ["INTERMEDIATE", "DEEP"]},
      groupby_cols='nfl_id',
      label = 'Variation by Defender ID - When Converging Deep'
  )
)


print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_role": 'Defensive Coverage',
        # 'team_coverage_man_zone': "ZONE_COVERAGE",
        "defender_type": "Converging",
        # 'pass_length_bin': ["INTERMEDIATE", "DEEP"],
        'route_type_of_targeted_receiver': "VERTICAL"
        },
      groupby_cols='nfl_id',
      label = 'Variation by Defender ID - When Converging Verts'
  )
)


print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_role": 'Defensive Coverage',
        # 'team_coverage_man_zone': "ZONE_COVERAGE",
        "defender_type": "Converging",
        'pass_length_bin': ["INTERMEDIATE", "DEEP"],
        'route_type_of_targeted_receiver': "VERTICAL"
        },
      groupby_cols='nfl_id',
      label = 'Variation by Defender ID - When Converging Deep Verts'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=15,
      filter_dict={
        "player_role": 'Defensive Coverage',
        # 'team_coverage_man_zone': "ZONE_COVERAGE",
        "defender_type": "Converging",
        # 'pass_length_bin': ["INTERMEDIATE", "DEEP"],
        # 'route_type_of_targeted_receiver': "VERTICAL",
        'team_coverage_man_zone': "MAN_COVERAGE"

        },
      groupby_cols='nfl_id',
      label = 'Variation by Defender ID - When Converging in Man'
  )
)


print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_role": 'Defensive Coverage',
        # 'team_coverage_man_zone': "ZONE_COVERAGE",
        "defender_type": "Trailing"},
      groupby_cols='nfl_id',
      label = 'Variation by Defender ID - When Trailing'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_role": 'Defensive Coverage',
        # 'team_coverage_man_zone': "ZONE_COVERAGE",
        "potential_contact": 1},
      groupby_cols='nfl_id',
      label = 'Variation by Defender ID - Potential Contact'
  )
)


print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_role": 'Defensive Coverage',
        # "defender_type": 'Trailing',
        # 'team_coverage_man_zone': "ZONE_COVERAGE"},
        "potential_contact": 1},
      groupby_cols='targeted_receiver_id',
      label = 'Variation by Targeted Receiver ID - Potential Contact'
  )
)
# Out:
# {'label': 'Variation by Defender ID - All', 'icc': np.float64(0.025944409685270318), 'var_between': np.float64(3.80945518528818e-05), 'var_within': np.float64(0.0014302199064448382), 'n_groups': 379, 'groupby': ['nfl_id'], 'filters': {'player_role': 'Defensive Coverage'}}
# {'label': 'Variation by Defender ID - On Vertical Routes', 'icc': np.float64(0.04439861075149015), 'var_between': np.float64(0.00010682757203089712), 'var_within': np.float64(0.0022992741104932947), 'n_groups': 201, 'groupby': ['nfl_id'], 'filters': {'player_role': 'Defensive Coverage', 'route_type_of_targeted_receiver': 'VERTICAL'}}
# {'label': 'Variation by Defender ID - On Out Breaking Routes', 'icc': np.float64(0.039062253038077685), 'var_between': np.float64(5.327810684724581e-05), 'var_within': np.float64(0.001310650051503236), 'n_groups': 125, 'groupby': ['nfl_id'], 'filters': {'player_role': 'Defensive Coverage', 'route_type_of_targeted_receiver': 'OUT_BREAK'}}
# {'label': 'Variation by Defender ID - On In Breaking Routes', 'icc': np.float64(0.04648320597829692), 'var_between': np.float64(5.048706698099842e-05), 'var_within': np.float64(0.001035648579612976), 'n_groups': 220, 'groupby': ['nfl_id'], 'filters': {'player_role': 'Defensive Coverage', 'route_type_of_targeted_receiver': 'IN_BREAK'}}
# {'label': 'Variation by Defender ID - On Short Pass Lengths', 'icc': np.float64(0.03087174974183034), 'var_between': np.float64(3.4662113396888235e-05), 'var_within': np.float64(0.0010881156263410723), 'n_groups': 299, 'groupby': ['nfl_id'], 'filters': {'player_role': 'Defensive Coverage', 'pass_length_bin': 'SHORT'}}
# {'label': 'Variation by Defender ID - On Intermediate Pass Lengths', 'icc': np.float64(0.05049352497712494), 'var_between': np.float64(9.885248603114359e-05), 'var_within': np.float64(0.0018588735011311052), 'n_groups': 234, 'groupby': ['nfl_id'], 'filters': {'player_role': 'Defensive Coverage', 'pass_length_bin': 'INTERMEDIATE'}}
# {'label': 'Variation by Defender ID - On Deep Pass Lengths', 'icc': np.float64(0.04840551934158409), 'var_between': np.float64(0.00010964032327752949), 'var_within': np.float64(0.0021553973164145203), 'n_groups': 100, 'groupby': ['nfl_id'], 'filters': {'player_role': 'Defensive Coverage', 'pass_length_bin': 'DEEP'}}
# {'label': 'Variation by Defender ID - On Quick Passes', 'icc': np.float64(0.03427945788840118), 'var_between': np.float64(3.1458741621454666e-05), 'var_within': np.float64(0.0008862553518706442), 'n_groups': 281, 'groupby': ['nfl_id'], 'filters': {'player_role': 'Defensive Coverage', 'num_output_frames_bin': 'QUICK'}}
# {'label': 'Variation by Defender ID - On Medium-Time Passes', 'icc': np.float64(0.035153973145106356), 'var_between': np.float64(6.884424206310721e-05), 'var_within': np.float64(0.0018895188077957604), 'n_groups': 279, 'groupby': ['nfl_id'], 'filters': {'player_role': 'Defensive Coverage', 'num_output_frames_bin': 'MEDIUM'}}
# {'label': 'Variation by Defender ID - On Long-Time Passes', 'icc': np.float64(0.10091001665539182), 'var_between': np.float64(0.00025477599058564547), 'var_within': np.float64(0.0022700079608005356), 'n_groups': 22, 'groupby': ['nfl_id'], 'filters': {'player_role': 'Defensive Coverage', 'num_output_frames_bin': 'LONG'}}
# {'label': 'Variation by Defender ID - Playing Man', 'icc': np.float64(0.045613951338057165), 'var_between': np.float64(0.00010392841912936949), 'var_within': np.float64(0.002174506491258644), 'n_groups': 207, 'groupby': ['nfl_id'], 'filters': {'player_role': 'Defensive Coverage', 'team_coverage_man_zone': 'MAN_COVERAGE'}}
# {'label': 'Variation by Defender ID - Playing Zone', 'icc': np.float64(0.03177245931083606), 'var_between': np.float64(4.147746555424838e-05), 'var_within': np.float64(0.0012639759508296198), 'n_groups': 339, 'groupby': ['nfl_id'], 'filters': {'player_role': 'Defensive Coverage', 'team_coverage_man_zone': 'ZONE_COVERAGE'}}
# {'label': 'Variation by Defender ID - When Converging', 'icc': np.float64(0.02149194463813332), 'var_between': np.float64(9.177289258163502e-06), 'var_within': np.float64(0.00041783336113594596), 'n_groups': 310, 'groupby': ['nfl_id'], 'filters': {'player_role': 'Defensive Coverage', 'defender_type': 'Converging'}}
# {'label': 'Variation by Defender ID - When Converging Deep', 'icc': np.float64(0.02988772243680687), 'var_between': np.float64(1.4425152817771887e-05), 'var_within': np.float64(0.00046821961371710613), 'n_groups': 196, 'groupby': ['nfl_id'], 'filters': {'player_role': 'Defensive Coverage', 'defender_type': 'Converging', 'pass_length_bin': ['INTERMEDIATE', 'DEEP']}}
# {'label': 'Variation by Defender ID - When Converging Verts', 'icc': np.float64(0.02918785881081179), 'var_between': np.float64(1.9586257728743595e-05), 'var_within': np.float64(0.0006514550082886335), 'n_groups': 93, 'groupby': ['nfl_id'], 'filters': {'player_role': 'Defensive Coverage', 'defender_type': 'Converging', 'route_type_of_targeted_receiver': 'VERTICAL'}}
# {'label': 'Variation by Defender ID - When Converging Deep Verts', 'icc': np.float64(0.02972295569608096), 'var_between': np.float64(2.1203906610289226e-05), 'var_within': np.float64(0.0006921809541384354), 'n_groups': 86, 'groupby': ['nfl_id'], 'filters': {'player_role': 'Defensive Coverage', 'defender_type': 'Converging', 'pass_length_bin': ['INTERMEDIATE', 'DEEP'], 'route_type_of_targeted_receiver': 'VERTICAL'}}
# {'label': 'Variation by Defender ID - When Converging in Man', 'icc': np.float64(0.04486420012601272), 'var_between': np.float64(1.2020173132065501e-05), 'var_within': np.float64(0.000255903318166202), 'n_groups': 131, 'groupby': ['nfl_id'], 'filters': {'player_role': 'Defensive Coverage', 'defender_type': 'Converging', 'team_coverage_man_zone': 'MAN_COVERAGE'}}
# {'label': 'Variation by Defender ID - When Trailing', 'icc': np.float64(0.0413968823870826), 'var_between': np.float64(0.00012469530032873557), 'var_within': np.float64(0.002887495307716793), 'n_groups': 256, 'groupby': ['nfl_id'], 'filters': {'player_role': 'Defensive Coverage', 'defender_type': 'Trailing'}}
# {'label': 'Variation by Defender ID - Potential Contact', 'icc': np.float64(0.04383240524466321), 'var_between': np.float64(0.0007207297473636076), 'var_within': np.float64(0.01572212214133943), 'n_groups': 4, 'groupby': ['nfl_id'], 'filters': {'player_role': 'Defensive Coverage', 'potential_contact': 1}}
# {'label': 'Variation by Targeted Receiver ID - Potential Contact', 'icc': np.float64(0.0377948172647225), 'var_between': np.float64(0.0005414647954487286), 'var_within': np.float64(0.013784964980787526), 'n_groups': 10, 'groupby': ['targeted_receiver_id'], 'filters': {'player_role': 'Defensive Coverage', 'potential_contact': 1}}

# %%
# ======================
# Variation by Safety (All Roles)
# ======================

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=15,
      filter_dict={'player_position': ['SS', 'FS', 'S']},
      groupby_cols='nfl_id',
      label = 'Variation by Safety ID - All'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_position": ['SS', 'FS', 'S'],
        'route_type_of_targeted_receiver': "VERTICAL"},
      groupby_cols='nfl_id',
      label = 'Variation by Safety ID - On Vertical Routes'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_position": ['SS', 'FS', 'S'],
        'route_type_of_targeted_receiver': "OUT_BREAK"},
      groupby_cols='nfl_id',
      label = 'Variation by Safety ID - On Out Breaking Routes'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_position": ['SS', 'FS', 'S'],
        'route_type_of_targeted_receiver': "IN_BREAK"},
      groupby_cols='nfl_id',
      label = 'Variation by Safety ID - On In Breaking Routes'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_position": ['SS', 'FS', 'S'],
        'pass_length_bin': "SHORT"},
      groupby_cols='nfl_id',
      label = 'Variation by Safety ID - On Short Pass Lengths'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_position": ['SS', 'FS', 'S'],
        'pass_length_bin': "INTERMEDIATE"},
      groupby_cols='nfl_id',
      label = 'Variation by Safety ID - On Intermediate Pass Lengths'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_position": ['SS', 'FS', 'S'],
        'pass_length_bin': "DEEP"},
      groupby_cols='nfl_id',
      label = 'Variation by Safety ID - On Deep Pass Lengths'
  )
)


print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_position": ['SS', 'FS', 'S'],
        'num_output_frames_bin': "QUICK"},
      groupby_cols='nfl_id',
      label = 'Variation by Safety ID - On Quick Passes'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_position": ['SS', 'FS', 'S'],
        'num_output_frames_bin': "MEDIUM"},
      groupby_cols='nfl_id',
      label = 'Variation by Safety ID - On Medium-Time Passes'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_position": ['SS', 'FS', 'S'],
        'num_output_frames_bin': "LONG"},
      groupby_cols='nfl_id',
      label = 'Variation by Safety ID - On Long-Time Passes'
  )
)


print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_position": ['SS', 'FS', 'S'],
        'team_coverage_man_zone': "MAN_COVERAGE"},
      groupby_cols='nfl_id',
      label = 'Variation by Safety ID - Playing Man'
  )
)
print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_position": ['SS', 'FS', 'S'],
        'team_coverage_man_zone': "ZONE_COVERAGE"},
      groupby_cols='nfl_id',
      label = 'Variation by Safety ID - Playing Zone'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_position": ['SS', 'FS', 'S'],
        # 'team_coverage_man_zone': "ZONE_COVERAGE",
        "defender_type": "Converging"},
      groupby_cols='nfl_id',
      label = 'Variation by Safety ID - When Converging'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_position": ['SS', 'FS', 'S'],
        # 'team_coverage_man_zone': "ZONE_COVERAGE",
        "defender_type": "Converging",
        'pass_length_bin': ["INTERMEDIATE", "DEEP"]
        },
      groupby_cols='nfl_id',
      label = 'Variation by Safety ID - When Converging Deep'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_position": ['SS', 'FS', 'S'],
        # 'team_coverage_man_zone': "ZONE_COVERAGE",
        "defender_type": "Trailing"},
      groupby_cols='nfl_id',
      label = 'Variation by Safety ID - When Trailing'
  )
)
# Out:
# {'label': 'Variation by Safety ID - All', 'icc': np.float64(0.019790022911376652), 'var_between': np.float64(2.0393105154213143e-05), 'var_within': np.float64(0.0010100809496529594), 'n_groups': 129, 'groupby': ['nfl_id'], 'filters': {'player_position': ['SS', 'FS', 'S']}}
# {'label': 'Variation by Safety ID - On Vertical Routes', 'icc': np.float64(0.02723648132834352), 'var_between': np.float64(3.3241645030514606e-05), 'var_within': np.float64(0.0011872407157332396), 'n_groups': 84, 'groupby': ['nfl_id'], 'filters': {'player_position': ['SS', 'FS', 'S'], 'route_type_of_targeted_receiver': 'VERTICAL'}}
# {'label': 'Variation by Safety ID - On Out Breaking Routes', 'icc': np.float64(0.054210742685686465), 'var_between': np.float64(8.245064147663499e-05), 'var_within': np.float64(0.0014384774512204762), 'n_groups': 20, 'groupby': ['nfl_id'], 'filters': {'player_position': ['SS', 'FS', 'S'], 'route_type_of_targeted_receiver': 'OUT_BREAK'}}
# {'label': 'Variation by Safety ID - On In Breaking Routes', 'icc': np.float64(0.04623814882963152), 'var_between': np.float64(4.166696340236726e-05), 'var_within': np.float64(0.0008594712624356265), 'n_groups': 69, 'groupby': ['nfl_id'], 'filters': {'player_position': ['SS', 'FS', 'S'], 'route_type_of_targeted_receiver': 'IN_BREAK'}}
# {'label': 'Variation by Safety ID - On Short Pass Lengths', 'icc': np.float64(0.03525795204345172), 'var_between': np.float64(3.6698930940899665e-05), 'var_within': np.float64(0.0010041706832576815), 'n_groups': 81, 'groupby': ['nfl_id'], 'filters': {'player_position': ['SS', 'FS', 'S'], 'pass_length_bin': 'SHORT'}}
# {'label': 'Variation by Safety ID - On Intermediate Pass Lengths', 'icc': np.float64(0.039977685581941744), 'var_between': np.float64(4.2470163429559136e-05), 'var_within': np.float64(0.0010198765635341266), 'n_groups': 74, 'groupby': ['nfl_id'], 'filters': {'player_position': ['SS', 'FS', 'S'], 'pass_length_bin': 'INTERMEDIATE'}}
# {'label': 'Variation by Safety ID - On Deep Pass Lengths', 'icc': np.float64(0.033296219442309774), 'var_between': np.float64(3.6384679538343316e-05), 'var_within': np.float64(0.0010563724006276112), 'n_groups': 52, 'groupby': ['nfl_id'], 'filters': {'player_position': ['SS', 'FS', 'S'], 'pass_length_bin': 'DEEP'}}
# {'label': 'Variation by Safety ID - On Quick Passes', 'icc': np.float64(0.040809873645400535), 'var_between': np.float64(3.83095544980988e-05), 'var_within': np.float64(0.0009004229402646354), 'n_groups': 75, 'groupby': ['nfl_id'], 'filters': {'player_position': ['SS', 'FS', 'S'], 'num_output_frames_bin': 'QUICK'}}
# {'label': 'Variation by Safety ID - On Medium-Time Passes', 'icc': np.float64(0.022789544784510098), 'var_between': np.float64(2.435466730878196e-05), 'var_within': np.float64(0.0010443225502078956), 'n_groups': 94, 'groupby': ['nfl_id'], 'filters': {'player_position': ['SS', 'FS', 'S'], 'num_output_frames_bin': 'MEDIUM'}}
# {'label': 'Variation by Safety ID - On Long-Time Passes', 'icc': np.float64(0.040804545736331806), 'var_between': np.float64(4.180745862923344e-05), 'var_within': np.float64(0.0009827710013144747), 'n_groups': 14, 'groupby': ['nfl_id'], 'filters': {'player_position': ['SS', 'FS', 'S'], 'num_output_frames_bin': 'LONG'}}
# {'label': 'Variation by Safety ID - Playing Man', 'icc': np.float64(0.05477022255274666), 'var_between': np.float64(6.867142433469167e-05), 'var_within': np.float64(0.0011851380570592795), 'n_groups': 71, 'groupby': ['nfl_id'], 'filters': {'player_position': ['SS', 'FS', 'S'], 'team_coverage_man_zone': 'MAN_COVERAGE'}}
# {'label': 'Variation by Safety ID - Playing Zone', 'icc': np.float64(0.02053921958450896), 'var_between': np.float64(2.151602648131019e-05), 'var_within': np.float64(0.001026042104575332), 'n_groups': 106, 'groupby': ['nfl_id'], 'filters': {'player_position': ['SS', 'FS', 'S'], 'team_coverage_man_zone': 'ZONE_COVERAGE'}}
# {'label': 'Variation by Safety ID - When Converging', 'icc': np.float64(0.01877904814466078), 'var_between': np.float64(1.0746126760003449e-05), 'var_within': np.float64(0.0005614940995402186), 'n_groups': 106, 'groupby': ['nfl_id'], 'filters': {'player_position': ['SS', 'FS', 'S'], 'defender_type': 'Converging'}}
# {'label': 'Variation by Safety ID - When Converging Deep', 'icc': np.float64(0.021962879520241157), 'var_between': np.float64(1.4410006663980258e-05), 'var_within': np.float64(0.0006416973425886479), 'n_groups': 91, 'groupby': ['nfl_id'], 'filters': {'player_position': ['SS', 'FS', 'S'], 'defender_type': 'Converging', 'pass_length_bin': ['INTERMEDIATE', 'DEEP']}}
# {'label': 'Variation by Safety ID - When Trailing', 'icc': np.float64(0.05498740366368069), 'var_between': np.float64(0.00013261761108752837), 'var_within': np.float64(0.002279164038009001), 'n_groups': 60, 'groupby': ['nfl_id'], 'filters': {'player_position': ['SS', 'FS', 'S'], 'defender_type': 'Trailing'}}

# %%
# ======================
# Variation by Cornerback (All Roles)
# ======================

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=15,
      filter_dict={'player_position': ['CB']},
      groupby_cols='nfl_id',
      label = 'Variation by Cornerback ID - All'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_position": ['CB'],
        'route_type_of_targeted_receiver': "VERTICAL"},
      groupby_cols='nfl_id',
      label = 'Variation by Cornerback ID - On Vertical Routes'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_position": ['CB'],
        'route_type_of_targeted_receiver': "OUT_BREAK"},
      groupby_cols='nfl_id',
      label = 'Variation by Cornerback ID - On Out Breaking Routes'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_position": ['CB'],
        'route_type_of_targeted_receiver': "IN_BREAK"},
      groupby_cols='nfl_id',
      label = 'Variation by Cornerback ID - On In Breaking Routes'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_position": ['CB'],
        'pass_length_bin': "SHORT"},
      groupby_cols='nfl_id',
      label = 'Variation by Cornerback ID - On Short Pass Lengths'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_position": ['CB'],
        'pass_length_bin': "INTERMEDIATE"},
      groupby_cols='nfl_id',
      label = 'Variation by Cornerback ID - On Intermediate Pass Lengths'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_position": ['CB'],
        'pass_length_bin': "DEEP"},
      groupby_cols='nfl_id',
      label = 'Variation by Cornerback ID - On Deep Pass Lengths'
  )
)


print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_position": ['CB'],
        'num_output_frames_bin': "QUICK"},
      groupby_cols='nfl_id',
      label = 'Variation by Cornerback ID - On Quick Passes'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_position": ['CB'],
        'num_output_frames_bin': "MEDIUM"},
      groupby_cols='nfl_id',
      label = 'Variation by Cornerback ID - On Medium-Time Passes'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_position": ['CB'],
        'num_output_frames_bin': "LONG"},
      groupby_cols='nfl_id',
      label = 'Variation by Cornerback ID - On Long-Time Passes'
  )
)


print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_position": ['CB'],
        'team_coverage_man_zone': "MAN_COVERAGE"},
      groupby_cols='nfl_id',
      label = 'Variation by Cornerback ID - Playing Man'
  )
)
print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_position": ['CB'],
        'team_coverage_man_zone': "ZONE_COVERAGE"},
      groupby_cols='nfl_id',
      label = 'Variation by Cornerback ID - Playing Zone'
  )
)


print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_position": ['CB'],
        # 'team_coverage_man_zone': "ZONE_COVERAGE",
        "defender_type": "Converging"},
      groupby_cols='nfl_id',
      label = 'Variation by Cornerback ID - When Converging'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_position": ['CB'],
        # 'team_coverage_man_zone': "ZONE_COVERAGE",
        "defender_type": "Trailing"},
      groupby_cols='nfl_id',
      label = 'Variation by Cornerback ID - When Trailing'
  )
)
# Out:
# {'label': 'Variation by Cornerback ID - All', 'icc': np.float64(0.021312060575582287), 'var_between': np.float64(5.307201718980894e-05), 'var_within': np.float64(0.002437161951580661), 'n_groups': 156, 'groupby': ['nfl_id'], 'filters': {'player_position': ['CB']}}
# {'label': 'Variation by Cornerback ID - On Vertical Routes', 'icc': np.float64(0.033342524002755856), 'var_between': np.float64(0.00014016428075868114), 'var_within': np.float64(0.004063605078366506), 'n_groups': 83, 'groupby': ['nfl_id'], 'filters': {'player_position': ['CB'], 'route_type_of_targeted_receiver': 'VERTICAL'}}
# {'label': 'Variation by Cornerback ID - On Out Breaking Routes', 'icc': np.float64(0.03403266922860391), 'var_between': np.float64(5.214703125264355e-05), 'var_within': np.float64(0.0014801168914612061), 'n_groups': 83, 'groupby': ['nfl_id'], 'filters': {'player_position': ['CB'], 'route_type_of_targeted_receiver': 'OUT_BREAK'}}
# {'label': 'Variation by Cornerback ID - On In Breaking Routes', 'icc': np.float64(0.03937789444885365), 'var_between': np.float64(6.731653633373605e-05), 'var_within': np.float64(0.0016421841181812169), 'n_groups': 86, 'groupby': ['nfl_id'], 'filters': {'player_position': ['CB'], 'route_type_of_targeted_receiver': 'IN_BREAK'}}
# {'label': 'Variation by Cornerback ID - On Short Pass Lengths', 'icc': np.float64(0.025978598340618927), 'var_between': np.float64(4.115109872264362e-05), 'var_within': np.float64(0.001542887354125741), 'n_groups': 130, 'groupby': ['nfl_id'], 'filters': {'player_position': ['CB'], 'pass_length_bin': 'SHORT'}}
# {'label': 'Variation by Cornerback ID - On Intermediate Pass Lengths', 'icc': np.float64(0.03762833120267405), 'var_between': np.float64(0.00012918926701396697), 'var_within': np.float64(0.003304108540378197), 'n_groups': 99, 'groupby': ['nfl_id'], 'filters': {'player_position': ['CB'], 'pass_length_bin': 'INTERMEDIATE'}}
# {'label': 'Variation by Cornerback ID - On Deep Pass Lengths', 'icc': np.float64(0.03608584741067463), 'var_between': np.float64(0.0001325809852537293), 'var_within': np.float64(0.003541462850959751), 'n_groups': 45, 'groupby': ['nfl_id'], 'filters': {'player_position': ['CB'], 'pass_length_bin': 'DEEP'}}
# {'label': 'Variation by Cornerback ID - On Quick Passes', 'icc': np.float64(0.03078169543784375), 'var_between': np.float64(3.8213515309971216e-05), 'var_within': np.float64(0.0012032228242553477), 'n_groups': 119, 'groupby': ['nfl_id'], 'filters': {'player_position': ['CB'], 'num_output_frames_bin': 'QUICK'}}
# {'label': 'Variation by Cornerback ID - On Medium-Time Passes', 'icc': np.float64(0.026671334799556436), 'var_between': np.float64(8.580346737803565e-05), 'var_within': np.float64(0.0031312633957120946), 'n_groups': 122, 'groupby': ['nfl_id'], 'filters': {'player_position': ['CB'], 'num_output_frames_bin': 'MEDIUM'}}
# {'label': 'Variation by Cornerback ID - On Long-Time Passes', 'icc': np.float64(0.08140280798884507), 'var_between': np.float64(0.0004007831242072913), 'var_within': np.float64(0.004522672639901143), 'n_groups': 8, 'groupby': ['nfl_id'], 'filters': {'player_position': ['CB'], 'num_output_frames_bin': 'LONG'}}
# {'label': 'Variation by Cornerback ID - Playing Man', 'icc': np.float64(0.03346784647811513), 'var_between': np.float64(0.00011290554947541785), 'var_within': np.float64(0.0032606473186258386), 'n_groups': 103, 'groupby': ['nfl_id'], 'filters': {'player_position': ['CB'], 'team_coverage_man_zone': 'MAN_COVERAGE'}}
# {'label': 'Variation by Cornerback ID - Playing Zone', 'icc': np.float64(0.029846909487494338), 'var_between': np.float64(6.231622193154639e-05), 'var_within': np.float64(0.002025545570179844), 'n_groups': 135, 'groupby': ['nfl_id'], 'filters': {'player_position': ['CB'], 'team_coverage_man_zone': 'ZONE_COVERAGE'}}
# {'label': 'Variation by Cornerback ID - When Converging', 'icc': np.float64(0.024746859138717797), 'var_between': np.float64(1.1706152791048213e-05), 'var_within': np.float64(0.0004613297474591498), 'n_groups': 121, 'groupby': ['nfl_id'], 'filters': {'player_position': ['CB'], 'defender_type': 'Converging'}}
# {'label': 'Variation by Cornerback ID - When Trailing', 'icc': np.float64(0.02876558229507991), 'var_between': np.float64(0.00012009893221331984), 'var_within': np.float64(0.004054992362005385), 'n_groups': 131, 'groupby': ['nfl_id'], 'filters': {'player_position': ['CB'], 'defender_type': 'Trailing'}}

# %%
# ======================
# Variation by Free Safety (All Roles)
# ======================

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=15,
      filter_dict={'player_position': ['FS']},
      groupby_cols='nfl_id',
      label = 'Variation by Safety ID - All'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_position": ['FS'],
        'route_type_of_targeted_receiver': "VERTICAL"},
      groupby_cols='nfl_id',
      label = 'Variation by Free Safety ID - On Vertical Routes'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_position": ['FS'],
        'route_type_of_targeted_receiver': "OUT_BREAK"},
      groupby_cols='nfl_id',
      label = 'Variation by Free Safety ID - On Out Breaking Routes'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_position": ['FS'],
        'route_type_of_targeted_receiver': "IN_BREAK"},
      groupby_cols='nfl_id',
      label = 'Variation by Free Safety ID - On In Breaking Routes'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_position": ['FS'],
        'pass_length_bin': "SHORT"},
      groupby_cols='nfl_id',
      label = 'Variation by Free Safety ID - On Short Pass Lengths'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_position": ['FS'],
        'pass_length_bin': "INTERMEDIATE"},
      groupby_cols='nfl_id',
      label = 'Variation by Free Safety ID - On Intermediate Pass Lengths'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_position": ['FS'],
        'pass_length_bin': "DEEP"},
      groupby_cols='nfl_id',
      label = 'Variation by Free Safety ID - On Deep Pass Lengths'
  )
)


print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_position": ['FS'],
        'num_output_frames_bin': "QUICK"},
      groupby_cols='nfl_id',
      label = 'Variation by Free Safety ID - On Quick Passes'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_position": ['FS'],
        'num_output_frames_bin': "MEDIUM"},
      groupby_cols='nfl_id',
      label = 'Variation by Free Safety ID - On Medium-Time Passes'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_position": ['FS'],
        'num_output_frames_bin': "LONG"},
      groupby_cols='nfl_id',
      label = 'Variation by Free Safety ID - On Long-Time Passes'
  )
)


print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_position": ['FS'],
        'team_coverage_man_zone': "MAN_COVERAGE"},
      groupby_cols='nfl_id',
      label = 'Variation by Free Safety ID - Playing Man'
  )
)
print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_position": ['FS'],
        'team_coverage_man_zone': "ZONE_COVERAGE"},
      groupby_cols='nfl_id',
      label = 'Variation by Free Safety ID - Playing Zone'
  )
)
# Out:
# {'label': 'Variation by Safety ID - All', 'icc': np.float64(0.016544552125932258), 'var_between': np.float64(1.6612187298893032e-05), 'var_within': np.float64(0.00098747587579559), 'n_groups': 73, 'groupby': ['nfl_id'], 'filters': {'player_position': ['FS']}}
# {'label': 'Variation by Free Safety ID - On Vertical Routes', 'icc': np.float64(0.030066082045318857), 'var_between': np.float64(3.7417175554839936e-05), 'var_within': np.float64(0.0012070807107490927), 'n_groups': 49, 'groupby': ['nfl_id'], 'filters': {'player_position': ['FS'], 'route_type_of_targeted_receiver': 'VERTICAL'}}
# {'label': 'Variation by Free Safety ID - On Out Breaking Routes', 'icc': np.float64(0.06735765874562885), 'var_between': np.float64(5.3532559083843954e-05), 'var_within': np.float64(0.000741218328651219), 'n_groups': 9, 'groupby': ['nfl_id'], 'filters': {'player_position': ['FS'], 'route_type_of_targeted_receiver': 'OUT_BREAK'}}
# {'label': 'Variation by Free Safety ID - On In Breaking Routes', 'icc': np.float64(0.048578724046397105), 'var_between': np.float64(4.139992982659014e-05), 'var_within': np.float64(0.0008108235618206881), 'n_groups': 37, 'groupby': ['nfl_id'], 'filters': {'player_position': ['FS'], 'route_type_of_targeted_receiver': 'IN_BREAK'}}
# {'label': 'Variation by Free Safety ID - On Short Pass Lengths', 'icc': np.float64(0.03269109744774403), 'var_between': np.float64(2.9085908701752845e-05), 'var_within': np.float64(0.000860633647157331), 'n_groups': 45, 'groupby': ['nfl_id'], 'filters': {'player_position': ['FS'], 'pass_length_bin': 'SHORT'}}
# {'label': 'Variation by Free Safety ID - On Intermediate Pass Lengths', 'icc': np.float64(0.033536441836545396), 'var_between': np.float64(3.895535565663289e-05), 'var_within': np.float64(0.0011226274934273265), 'n_groups': 41, 'groupby': ['nfl_id'], 'filters': {'player_position': ['FS'], 'pass_length_bin': 'INTERMEDIATE'}}
# {'label': 'Variation by Free Safety ID - On Deep Pass Lengths', 'icc': np.float64(0.04210293882432405), 'var_between': np.float64(5.01288178494498e-05), 'var_within': np.float64(0.0011404963320626265), 'n_groups': 28, 'groupby': ['nfl_id'], 'filters': {'player_position': ['FS'], 'pass_length_bin': 'DEEP'}}
# {'label': 'Variation by Free Safety ID - On Quick Passes', 'icc': np.float64(0.04667196715085112), 'var_between': np.float64(4.5059330028727176e-05), 'var_within': np.float64(0.000920388084756434), 'n_groups': 42, 'groupby': ['nfl_id'], 'filters': {'player_position': ['FS'], 'num_output_frames_bin': 'QUICK'}}
# {'label': 'Variation by Free Safety ID - On Medium-Time Passes', 'icc': np.float64(0.019540314017939785), 'var_between': np.float64(2.3444727795055533e-05), 'var_within': np.float64(0.0011763685287130609), 'n_groups': 54, 'groupby': ['nfl_id'], 'filters': {'player_position': ['FS'], 'num_output_frames_bin': 'MEDIUM'}}
# {'label': 'Variation by Free Safety ID - On Long-Time Passes', 'icc': np.float64(0.047871491689705926), 'var_between': np.float64(6.274803576747904e-05), 'var_within': np.float64(0.0012480119500336757), 'n_groups': 9, 'groupby': ['nfl_id'], 'filters': {'player_position': ['FS'], 'num_output_frames_bin': 'LONG'}}
# {'label': 'Variation by Free Safety ID - Playing Man', 'icc': np.float64(0.060681103900988874), 'var_between': np.float64(6.905846551984996e-05), 'var_within': np.float64(0.0010689970588577244), 'n_groups': 37, 'groupby': ['nfl_id'], 'filters': {'player_position': ['FS'], 'team_coverage_man_zone': 'MAN_COVERAGE'}}
# {'label': 'Variation by Free Safety ID - Playing Zone', 'icc': np.float64(0.019427542711592423), 'var_between': np.float64(2.17693301604792e-05), 'var_within': np.float64(0.0010987702297648957), 'n_groups': 58, 'groupby': ['nfl_id'], 'filters': {'player_position': ['FS'], 'team_coverage_man_zone': 'ZONE_COVERAGE'}}

# %%
print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=20,
      filter_dict={
        "player_role": 'Defensive Coverage',
        # 'team_coverage_man_zone': "ZONE_COVERAGE",
        "defender_type": "Converging",
        'pass_length_bin': ["INTERMEDIATE", "DEEP"],
        'route_type_of_targeted_receiver': "VERTICAL"
        },
      groupby_cols='nfl_id',
      label = 'Variation by Defender ID - When Converging Deep Verts'
  )
)

print(
  assess_icc_by_cut(
      player_impacts,
      min_plays=15,
      filter_dict={
        "player_role": 'Defensive Coverage',
        # 'team_coverage_man_zone': "ZONE_COVERAGE",
        "defender_type": "Converging",
        'pass_length_bin': ["INTERMEDIATE", "DEEP"],
        # 'route_type_of_targeted_receiver': "VERTICAL",
        # 'team_coverage_man_zone': "MAN_COVERAGE"
        },
      groupby_cols='nfl_id',
      label = 'Variation by Defender ID - When Converging in Man'
  )
)
# Out:
# {'label': 'Variation by Defender ID - When Converging Deep Verts', 'icc': np.float64(0.02972295569608096), 'var_between': np.float64(2.1203906610289226e-05), 'var_within': np.float64(0.0006921809541384354), 'n_groups': 86, 'groupby': ['nfl_id'], 'filters': {'player_role': 'Defensive Coverage', 'defender_type': 'Converging', 'pass_length_bin': ['INTERMEDIATE', 'DEEP'], 'route_type_of_targeted_receiver': 'VERTICAL'}}
# {'label': 'Variation by Defender ID - When Converging in Man', 'icc': np.float64(0.03713509786240435), 'var_between': np.float64(1.8175065894241816e-05), 'var_within': np.float64(0.00047125587519511214), 'n_groups': 252, 'groupby': ['nfl_id'], 'filters': {'player_role': 'Defensive Coverage', 'defender_type': 'Converging', 'pass_length_bin': ['INTERMEDIATE', 'DEEP']}}

# %%
rec_filtered = player_impacts[(player_impacts['player_role'] == 'Defensive Coverage')&
                          (player_impacts['potential_contact'] == 1)
                          # player_impacts['defender_type'].isin(['Trailing'])
                          # player_impacts['pass_length_bin'].isin(['INTERMEDIATE', 'DEEP'])
                          # (player_impacts['route_type_of_targeted_receiver'] == "VERTICAL")
                          # (player_impacts['team_coverage_man_zone'] == "MAN_COVERAGE")
                          # &(player_impacts['pass_length_bin'].isin(['DEEP']))
                          ].copy()

# rec_filtered[rec_filtered['delta'] > 0.05].groupby('targeted_receiver_id').count()[['play_id']].reset_index().sort_values('play_id',ascending = False)
# rec_filtered[rec_filtered['delta'] > 0.05].groupby('targeted_receiver_id').count()[['nfl_id']].reset_index().sort_values('nfl_id',ascending = False)
# rec_res = rec_filtered.groupby('targeted_receiver_id').agg(
#     mean_delta=('delta', 'mean'),
#     std_delta=('delta', 'std'),
#     n_plays=('delta', 'count')
# ).query('n_plays >= 15')

# rec_res.reset_index(inplace = True)

# rec_res.sort_values('mean_delta', ascending= False)
# Out:
#     targeted_receiver_id  nfl_id
# 7                  41282       5
# 73                 54476       4
# 5                  41233       4
# 41                 47859       3
# 45                 48097       3
# ..                   ...     ...
# 42                 47879       1
# 40                 47852       1
# 39                 47849       1
# 36                 47819       1
# 99                 56220       1
#
# [100 rows x 2 columns]

# %%
# KEEP THIS, this is good for help coverage analysis
filtered = player_impacts[(player_impacts['player_role'] == 'Defensive Coverage')&
                          player_impacts['defender_type'].isin(['Converging'])&
                          player_impacts['pass_length_bin'].isin(['INTERMEDIATE', 'DEEP'])
                          # (player_impacts['route_type_of_targeted_receiver'] == "VERTICAL")
                          # (player_impacts['team_coverage_man_zone'] == "MAN_COVERAGE")
                          # &(player_impacts['pass_length_bin'].isin(['DEEP']))
                          ]
res = filtered.groupby('nfl_id').agg(
    mean_delta=('delta', 'mean'),
    std_delta=('delta', 'std'),
    n_plays=('delta', 'count')
).query('n_plays >= 15')

res.reset_index(inplace= True)
res.sort_values('mean_delta', ascending= False)

filtered[filtered['delta'] < -.01].groupby('nfl_id').count().reset_index().sort_values('play_id', ascending = False)
# Out:
#      nfl_id  game_id  play_id  player_role  baseline_prob  real_prob  delta  \
# 148   53554       10       10           10             10         10     10
# 160   54502        9        9            9              9          9      9
# 159   54496        7        7            7              7          7      7
# 70    46304        6        6            6              6          6      6
# 2     38559        6        6            6              6          6      6
# ..      ...      ...      ...          ...            ...        ...    ...
# 100   47947        1        1            1              1          1      1
# 99    47941        1        1            1              1          1      1
# 98    47938        1        1            1              1          1      1
# 97    47934        1        1            1              1          1      1
# 218   56598        1        1            1              1          1      1
#
#      fold  pass_result  yards_gained  season  week  home_team_abbr  \
# 148    10           10            10      10    10              10
# 160     9            9             9       9     9               9
# 159     7            7             7       7     7               7
# 70      6            6             6       6     6               6
# 2       6            6             6       6     6               6
# ..    ...          ...           ...     ...   ...             ...
# 100     1            1             1       1     1               1
# 99      1            1             1       1     1               1
# 98      1            1             1       1     1               1
# 97      1            1             1       1     1               1
# 218     1            1             1       1     1               1
#
#      visitor_team_abbr  play_description  quarter  game_clock  \
# 148                 10                10       10          10
# 160                  9                 9        9           9
# 159                  7                 7        7           7
# 70                   6                 6        6           6
# 2                    6                 6        6           6
# ..                 ...               ...      ...         ...
# 100                  1                 1        1           1
# 99                   1                 1        1           1
# 98                   1                 1        1           1
# 97                   1                 1        1           1
# 218                  1                 1        1           1
#
#      player_position  passer_nfl_id  num_output_frames  num_output_frames_bin  \
# 148               10             10                 10                     10
# 160                9              9                  9                      9
# 159                7              7                  7                      7
# 70                 6              6                  6                      6
# 2                  6              6                  6                      6
# ..               ...            ...                ...                    ...
# 100                1              1                  1                      1
# 99                 1              1                  1                      1
# 98                 1              1                  1                      1
# 97                 1              1                  1                      1
# 218                1              1                  1                      1
#
#      possession_team  defensive_team  down_and_distance  receiver_alignment  \
# 148               10              10                 10                  10
# 160                9               9                  9                   9
# 159                7               7                  7                   7
# 70                 6               6                  6                   6
# 2                  6               6                  6                   6
# ..               ...             ...                ...                 ...
# 100                1               1                  1                   1
# 99                 1               1                  1                   1
# 98                 1               1                  1                   1
# 97                 1               1                  1                   1
# 218                1               1                  1                   1
#
#      route_of_targeted_receiver  route_type_of_targeted_receiver  pass_length  \
# 148                          10                               10           10
# 160                           9                                9            9
# 159                           7                                7            7
# 70                            6                                6            6
# 2                             6                                6            6
# ..                          ...                              ...          ...
# 100                           1                                1            1
# 99                            1                                1            1
# 98                            1                                1            1
# 97                            1                                1            1
# 218                           1                                1            1
#
#      pass_length_bin  dropback_type  team_coverage_man_zone  \
# 148               10             10                      10
# 160                9              9                       9
# 159                7              7                       7
# 70                 6              6                       6
# 2                  6              6                       6
# ..               ...            ...                     ...
# 100                1              1                       1
# 99                 1              1                       1
# 98                 1              1                       1
# 97                 1              1                       1
# 218                1              1                       1
#
#      team_coverage_type  defender_type  potential_contact  \
# 148                  10             10                 10
# 160                   9              9                  9
# 159                   7              7                  7
# 70                    6              6                  6
# 2                     6              6                  6
# ..                  ...            ...                ...
# 100                   1              1                  1
# 99                    1              1                  1
# 98                    1              1                  1
# 97                    1              1                  1
# 218                   1              1                  1
#
#      targeted_receiver_id
# 148                    10
# 160                     9
# 159                     7
# 70                      6
# 2                       6
# ..                    ...
# 100                     1
# 99                      1
# 98                      1
# 97                      1
# 218                     1
#
# [219 rows x 35 columns]

# %%
filtered.sort_values('delta', ascending= False).head(40)
# Out:
#           game_id  play_id  nfl_id         player_role  baseline_prob  \
# 35113  2023121001     1563   44854  Defensive Coverage       0.185205
# 32625  2023110900      138   46124  Defensive Coverage       0.167636
# 20791  2023102210     2653   46097  Defensive Coverage       0.606598
# 45910  2024010710     3357   54718  Defensive Coverage       0.530305
# 36032  2023121709     2202   53437  Defensive Coverage       0.208238
# 12973  2023102905      795   55888  Defensive Coverage       0.067568
# 43572  2023121002     1009   52458  Defensive Coverage       0.095109
# 11603  2023101500     2935   52627  Defensive Coverage       0.114005
# 12093  2023101507     3107   52939  Defensive Coverage       0.462516
# 12170  2023101511     1288   41243  Defensive Coverage       0.369972
# 23697  2023120304     3059   52453  Defensive Coverage       0.267854
# 45017  2023122407     1171   54500  Defensive Coverage       0.513139
# 36777  2023091007     2208   52535  Defensive Coverage       0.243902
# 2713   2023100810     2294   53554  Defensive Coverage       0.087882
# 45193  2023123101     1486   52627  Defensive Coverage       0.335511
# 11976  2023101507      946   52939  Defensive Coverage       0.169480
# 19203  2023092412      817   46080  Defensive Coverage       0.187422
# 12354  2023101512     1518   47872  Defensive Coverage       0.329966
# 34856  2023120307     3411   54468  Defensive Coverage       0.200380
# 7412   2023122403     1977   45004  Defensive Coverage       0.687062
# 37406  2023091702     2094   48026  Defensive Coverage       0.622682
# 40830  2023102300      542   38868  Defensive Coverage       0.495504
# 37427  2023091702     2483   52627  Defensive Coverage       0.165132
# 19922  2023100807     1715   53445  Defensive Coverage       0.316718
# 37785  2023091708     1325   53604  Defensive Coverage       0.801867
# 45755  2024010706     2310   47804  Defensive Coverage       0.572697
# 26549  2024010600     2756   44854  Defensive Coverage       0.448649
# 12774  2023102202     3858   54704  Defensive Coverage       0.072824
# 21718  2023110509     2073   53604  Defensive Coverage       0.220592
# 4164   2023102913     1544   46086  Defensive Coverage       0.318257
# 1141   2023092406     2489   45571  Defensive Coverage       0.160361
# 7611   2023122409     3081   54513  Defensive Coverage       0.422801
# 42354  2023111209     2898   42488  Defensive Coverage       0.317833
# 42771  2023112607     2131   48447  Defensive Coverage       0.732182
# 1144   2023092406     2489   52594  Defensive Coverage       0.164898
# 17185  2023122408     1019   52453  Defensive Coverage       0.727344
# 41410  2023110200     2677   55181  Defensive Coverage       0.695864
# 45188  2023123101     1486   44854  Defensive Coverage       0.381443
# 23866  2023120400     3293   55960  Defensive Coverage       0.233627
# 36298  2023122405     4435   53530  Defensive Coverage       0.103397
#
#        real_prob     delta  fold pass_result  yards_gained  season  week  \
# 35113   0.584084  0.398879     4           I             0    2023    14
# 32625   0.435925  0.268289     4           I             0    2023    10
# 20791   0.858516  0.251918     3           I             0    2023     7
# 45910   0.767554  0.237249     5           I             0    2023    18
# 36032   0.429996  0.221758     4           I             0    2023    15
# 12973   0.284091  0.216523     2           I             0    2023     8
# 43572   0.295785  0.200676     5          IN             0    2023    14
# 11603   0.298792  0.184788     2          IN             0    2023     6
# 12093   0.640255  0.177740     2           C            13    2023     6
# 12170   0.545552  0.175580     2           C            14    2023     6
# 23697   0.442438  0.174585     3           I             0    2023    13
# 45017   0.687140  0.174001     5           C            26    2023    16
# 36777   0.415460  0.171558     5           I             0    2023     1
# 2713    0.258837  0.170955     1           C            33    2023     5
# 45193   0.503809  0.168298     5           C            16    2023    17
# 11976   0.334974  0.165494     2           I             0    2023     6
# 19203   0.352019  0.164597     3           I             0    2023     3
# 12354   0.486845  0.156879     2           I             0    2023     6
# 34856   0.354157  0.153777     4          IN             0    2023    13
# 7412    0.835856  0.148794     1           C            21    2023    16
# 37406   0.771470  0.148789     5           I             0    2023     2
# 40830   0.643799  0.148295     5           C            20    2023     7
# 37427   0.313410  0.148278     5          IN             0    2023     2
# 19922   0.459206  0.142488     3           C            14    2023     5
# 37785   0.943008  0.141141     5           C            22    2023     2
# 45755   0.713002  0.140305     5           C            27    2023    18
# 26549   0.588359  0.139710     3           C            71    2023    18
# 12774   0.210785  0.137961     2          IN             0    2023     7
# 21718   0.357753  0.137161     3           I             0    2023     9
# 4164    0.451883  0.133625     1           I             0    2023     8
# 1141    0.289422  0.129062     1           I             0    2023     3
# 7611    0.550291  0.127491     1           I             0    2023    16
# 42354   0.444113  0.126280     5           I             0    2023    10
# 42771   0.857266  0.125083     5           C            23    2023    12
# 1144    0.289422  0.124524     1           I             0    2023     3
# 17185   0.851799  0.124455     2           C            23    2023    16
# 41410   0.819346  0.123482     5           I             0    2023     9
# 45188   0.503809  0.122366     5           C            16    2023    17
# 23866   0.354143  0.120515     3           C            21    2023    13
# 36298   0.223595  0.120198     4          IN             0    2023    16
#
#       home_team_abbr visitor_team_abbr  \
# 35113            BAL                LA
# 32625            CHI               CAR
# 20791            PHI               MIA
# 45910             SF                LA
# 36032            CAR               ATL
# 12973            NYG               NYJ
# 43572            CHI               DET
# 11603            TEN               BAL
# 12093            MIA               CAR
# 12170            NYJ               PHI
# 23697             TB               CAR
# 45017            TEN               SEA
# 36777            WAS               ARI
# 2713             MIN                KC
# 45193            BAL               MIA
# 11976            MIA               CAR
# 19203             LV               PIT
# 12354            BUF               NYG
# 34856            HOU               DEN
# 7412             CAR                GB
# 37406            CIN               BAL
# 40830            MIN                SF
# 37427            CIN               BAL
# 19922            ARI               CIN
# 37785            ARI               NYG
# 45755             GB               CHI
# 26549            BAL               PIT
# 12774            IND               CLE
# 21718             LV               NYG
# 4164             LAC               CHI
# 1141             MIN               LAC
# 7611             CHI               ARI
# 42354            DAL               NYG
# 42771            DEN               CLE
# 1144             MIN               LAC
# 17185             TB               JAX
# 41410            PIT               TEN
# 45188            BAL               MIA
# 23866            JAX               CIN
# 36298            MIN               DET
#
#                                         play_description  quarter game_clock  \
# 35113  (5:59) M.Stafford pass incomplete deep left to...        2      05:59
# 32625  (13:36) (Shotgun) T.Bagent pass incomplete sho...        1      13:36
# 20791  (4:20) (Shotgun) T.Tagovailoa pass incomplete ...        3      04:20
# 45910  (4:56) (Shotgun) S.Darnold pass incomplete dee...        4      04:56
# 36032  (11:37) D.Ridder pass incomplete deep right to...        3      11:37
# 12973  (3:25) (Shotgun) Z.Wilson pass incomplete shor...        1      03:25
# 43572  (14:12) (Shotgun) J.Goff pass deep right inten...        2      14:12
# 11603  (4:43) (Shotgun) R.Tannehill pass deep right i...        3      04:43
# 12093  (14:24) T.Tagovailoa pass short middle to T.Hi...        4      14:24
# 12170  (13:12) (Shotgun) J.Hurts pass short middle to...        2      13:12
# 23697  (4:49) (Shotgun) B.Young pass incomplete deep ...        3      04:49
# 45017  (13:03) (No Huddle, Shotgun) G.Smith pass shor...        2      13:03
# 36777  (:19) (Shotgun) S.Howell pass incomplete short...        2      00:19
# 2713   (13:45) (Shotgun) P.Mahomes pass deep left to ...        3      13:45
# 45193  (6:08) (Shotgun) T.Tagovailoa pass deep middle...        2      06:08
# 11976  (15:00) (Shotgun) T.Tagovailoa pass incomplete...        2      15:00
# 19203  (4:47) (Shotgun) J.Garoppolo pass incomplete d...        1      04:47
# 12354  (9:48) J.Allen pass incomplete short middle to...        2      09:48
# 34856  (9:40) (Shotgun) R.Wilson pass deep middle int...        4      09:40
# 7412   (:57) (Shotgun) J.Love pass deep right to D.Wi...        2      00:57
# 37406  (:15) (Shotgun) L.Jackson pass incomplete shor...        2      00:15
# 40830  (4:52) (Shotgun) K.Cousins pass deep right to ...        1      04:52
# 37427  (10:48) (Shotgun) J.Burrow pass short middle i...        3      10:48
# 19922  (3:16) (Shotgun) J.Burrow pass short middle to...        2      03:16
# 37785  (11:19) (Shotgun) J.Dobbs pass short right to ...        2      11:19
# 45755  (14:43) (Shotgun) J.Fields pass deep middle to...        4      14:43
# 26549  (15:00) (Shotgun) M.Rudolph pass deep middle t...        4      15:00
# 12774  (11:14) (Shotgun) P.Walker pass deep left inte...        4      11:14
# 21718  (13:00) (Shotgun) A.O'Connell pass incomplete ...        3      13:00
# 4164   (5:22) (Shotgun) T.Bagent pass incomplete deep...        2      05:22
# 1141   (14:00) (Shotgun) K.Cousins pass incomplete de...        3      14:00
# 7611   (:21) (Shotgun) K.Murray pass incomplete deep ...        3      00:21
# 42354  (2:24) D.Prescott pass incomplete deep right t...        3      02:24
# 42771  (1:06) (Shotgun) D.Thompson-Robinson pass shor...        2      01:06
# 1144   (14:00) (Shotgun) K.Cousins pass incomplete de...        3      14:00
# 17185  (11:06) (Shotgun) T.Lawrence pass deep middle ...        2      11:06
# 41410  (5:49) (Shotgun) K.Pickett pass incomplete sho...        3      05:49
# 45188  (6:08) (Shotgun) T.Tagovailoa pass deep middle...        2      06:08
# 23866  (9:27) B.Hance reported in as eligible.  T.Law...        4      09:27
# 36298  (:58) (Shotgun) N.Mullens pass deep middle int...        4      00:58
#
#       player_position  passer_nfl_id  num_output_frames num_output_frames_bin  \
# 35113              FS        34452.0                 20                MEDIUM
# 32625              CB        56167.0                 11                MEDIUM
# 20791              FS        52413.0                 11                MEDIUM
# 45910              FS        46072.0                 23                  LONG
# 36032              CB        54539.0                 14                MEDIUM
# 12973              CB        53431.0                 16                MEDIUM
# 43572              CB        43290.0                 14                MEDIUM
# 11603              FS        38538.0                 20                MEDIUM
# 12093              FS        52413.0                 12                MEDIUM
# 12170             ILB        52461.0                 11                MEDIUM
# 23697              FS        55865.0                 12                MEDIUM
# 45017              CB        39987.0                 13                MEDIUM
# 36777              FS        54609.0                 10                 QUICK
# 2713               FS        44822.0                 25                  LONG
# 45193              FS        52413.0                 12                MEDIUM
# 11976              FS        52413.0                 27                  LONG
# 19203              FS        41291.0                 20                MEDIUM
# 12354             ILB        46076.0                  7                 QUICK
# 34856              CB        38605.0                 21                  LONG
# 7412               FS        52434.0                 13                MEDIUM
# 37406              FS        46101.0                  9                 QUICK
# 40830              FS        38632.0                 14                MEDIUM
# 37427              FS        52409.0                 13                MEDIUM
# 19922             OLB        52409.0                 11                MEDIUM
# 37785              FS        44948.0                 10                 QUICK
# 45755              FS        53440.0                 14                MEDIUM
# 26549              FS        46145.0                 11                MEDIUM
# 12774              FS        45159.0                 29                  LONG
# 21718              FS        56000.0                 20                MEDIUM
# 4164               SS        56167.0                 31                  LONG
# 1141               CB        38632.0                 15                MEDIUM
# 7611               SS        47784.0                 15                MEDIUM
# 42354              SS        43424.0                 13                MEDIUM
# 42771              SS        56005.0                 11                MEDIUM
# 1144               FS        38632.0                 15                MEDIUM
# 17185              FS        53430.0                 14                MEDIUM
# 41410              CB        54485.0                 19                MEDIUM
# 45188              FS        52413.0                 12                MEDIUM
# 23866              SS        53430.0                 14                MEDIUM
# 36298              SS        45198.0                 18                MEDIUM
#
#       possession_team defensive_team down_and_distance receiver_alignment  \
# 35113              LA            BAL          1st_long                2x2
# 32625             CHI            CAR          3rd_long                2x2
# 20791             MIA            PHI         3rd_short                2x2
# 45910              SF             LA          1st_long                2x2
# 36032             ATL            CAR          2nd_long                2x1
# 12973             NYJ            NYG          1st_long                2x2
# 43572             DET            CHI          4th_down                3x1
# 11603             TEN            BAL         3rd_short                2x1
# 12093             MIA            CAR          2nd_long                2x2
# 12170             PHI            NYJ          1st_long                3x2
# 23697             CAR             TB          3rd_long                3x1
# 45017             SEA            TEN        2nd_medium                2x2
# 36777             WAS            ARI          1st_long                3x1
# 2713               KC            MIN          3rd_long                3x1
# 45193             MIA            BAL        3rd_medium                3x2
# 11976             MIA            CAR          1st_long                3x1
# 19203              LV            PIT        3rd_medium                3x1
# 12354             BUF            NYG        2nd_medium                3x1
# 34856             DEN            HOU        2nd_medium                3x2
# 7412               GB            CAR          3rd_long                3x2
# 37406             BAL            CIN          1st_long                3x1
# 40830             MIN             SF         3rd_short                3x1
# 37427             CIN            BAL          2nd_long                3x1
# 19922             CIN            ARI          3rd_long                2x2
# 37785             ARI            NYG          2nd_long                2x2
# 45755             CHI             GB          1st_long                3x1
# 26549             PIT            BAL        3rd_medium                3x2
# 12774             CLE            IND          3rd_long                3x1
# 21718              LV            NYG          1st_long                2x2
# 4164              CHI            LAC          2nd_long                2x2
# 1141              MIN            LAC         2nd_short                3x1
# 7611              ARI            CHI          2nd_long                2x2
# 42354             DAL            NYG          2nd_long                2x1
# 42771             CLE            DEN          1st_long                2x2
# 1144              MIN            LAC         2nd_short                3x1
# 17185             JAX             TB          3rd_long                3x1
# 41410             PIT            TEN         3rd_short                3x1
# 45188             MIA            BAL        3rd_medium                3x2
# 23866             JAX            CIN          1st_long                2x2
# 36298             MIN            DET          1st_long                3x2
#
#       route_of_targeted_receiver route_type_of_targeted_receiver  pass_length  \
# 35113                      CROSS                        IN_BREAK           20
# 32625                        OUT                       OUT_BREAK           12
# 20791                       POST                        VERTICAL           13
# 45910                      HITCH                      STOP_HITCH           35
# 36032                     CORNER                        VERTICAL           19
# 12973                         GO                        VERTICAL           14
# 43572                     CORNER                        VERTICAL           20
# 11603                     CORNER                        VERTICAL           28
# 12093                         IN                        IN_BREAK           13
# 12170                         IN                        IN_BREAK           12
# 23697                         IN                        IN_BREAK           19
# 45017                      HITCH                      STOP_HITCH           12
# 36777                         IN                        IN_BREAK           11
# 2713                       CROSS                        IN_BREAK           31
# 45193                       POST                        VERTICAL           16
# 11976                         GO                        VERTICAL           46
# 19203                      WHEEL                        VERTICAL           18
# 12354                       POST                        VERTICAL           14
# 34856                         GO                        VERTICAL           37
# 7412                        POST                        VERTICAL           20
# 37406                       POST                        VERTICAL           12
# 40830                      CROSS                        IN_BREAK           19
# 37427                       POST                        VERTICAL           15
# 19922                         IN                        IN_BREAK           13
# 37785                      SLANT                        IN_BREAK           12
# 45755                      HITCH                      STOP_HITCH           26
# 26549                       POST                        VERTICAL           16
# 12774                         GO                        VERTICAL           45
# 21718                         GO                        VERTICAL           27
# 4164                          GO                        VERTICAL           40
# 1141                          IN                        IN_BREAK           17
# 7611                          GO                        VERTICAL           16
# 42354                       POST                        VERTICAL           21
# 42771                         IN                        IN_BREAK           14
# 1144                          IN                        IN_BREAK           17
# 17185                       POST                        VERTICAL           20
# 41410                         GO                        VERTICAL           12
# 45188                       POST                        VERTICAL           16
# 23866                     CORNER                        VERTICAL           20
# 36298                       POST                        VERTICAL           25
#
#       pass_length_bin           dropback_type team_coverage_man_zone  \
# 35113    INTERMEDIATE   DESIGNED_ROLLOUT_LEFT          ZONE_COVERAGE
# 32625    INTERMEDIATE             TRADITIONAL          ZONE_COVERAGE
# 20791    INTERMEDIATE             TRADITIONAL          ZONE_COVERAGE
# 45910            DEEP                SCRAMBLE          ZONE_COVERAGE
# 36032    INTERMEDIATE  DESIGNED_ROLLOUT_RIGHT          ZONE_COVERAGE
# 12973    INTERMEDIATE             TRADITIONAL          ZONE_COVERAGE
# 43572    INTERMEDIATE             TRADITIONAL          ZONE_COVERAGE
# 11603            DEEP             TRADITIONAL          ZONE_COVERAGE
# 12093    INTERMEDIATE   DESIGNED_ROLLOUT_LEFT          ZONE_COVERAGE
# 12170    INTERMEDIATE             TRADITIONAL          ZONE_COVERAGE
# 23697    INTERMEDIATE             TRADITIONAL          ZONE_COVERAGE
# 45017    INTERMEDIATE             TRADITIONAL          ZONE_COVERAGE
# 36777    INTERMEDIATE             TRADITIONAL           MAN_COVERAGE
# 2713             DEEP             TRADITIONAL           MAN_COVERAGE
# 45193    INTERMEDIATE             TRADITIONAL          ZONE_COVERAGE
# 11976            DEEP             TRADITIONAL          ZONE_COVERAGE
# 19203    INTERMEDIATE             TRADITIONAL           MAN_COVERAGE
# 12354    INTERMEDIATE             TRADITIONAL          ZONE_COVERAGE
# 34856            DEEP             TRADITIONAL          ZONE_COVERAGE
# 7412     INTERMEDIATE                SCRAMBLE          ZONE_COVERAGE
# 37406    INTERMEDIATE             TRADITIONAL          ZONE_COVERAGE
# 40830    INTERMEDIATE             TRADITIONAL          ZONE_COVERAGE
# 37427    INTERMEDIATE             TRADITIONAL          ZONE_COVERAGE
# 19922    INTERMEDIATE             TRADITIONAL          ZONE_COVERAGE
# 37785    INTERMEDIATE             TRADITIONAL          ZONE_COVERAGE
# 45755            DEEP                SCRAMBLE          ZONE_COVERAGE
# 26549    INTERMEDIATE             TRADITIONAL          ZONE_COVERAGE
# 12774            DEEP             TRADITIONAL          ZONE_COVERAGE
# 21718            DEEP             TRADITIONAL           MAN_COVERAGE
# 4164             DEEP             TRADITIONAL          ZONE_COVERAGE
# 1141     INTERMEDIATE             TRADITIONAL           MAN_COVERAGE
# 7611     INTERMEDIATE             TRADITIONAL          ZONE_COVERAGE
# 42354            DEEP             TRADITIONAL          ZONE_COVERAGE
# 42771    INTERMEDIATE             TRADITIONAL          ZONE_COVERAGE
# 1144     INTERMEDIATE             TRADITIONAL           MAN_COVERAGE
# 17185    INTERMEDIATE             TRADITIONAL          ZONE_COVERAGE
# 41410    INTERMEDIATE             TRADITIONAL           MAN_COVERAGE
# 45188    INTERMEDIATE             TRADITIONAL          ZONE_COVERAGE
# 23866    INTERMEDIATE             TRADITIONAL          ZONE_COVERAGE
# 36298            DEEP             TRADITIONAL          ZONE_COVERAGE
#
#       team_coverage_type defender_type  potential_contact  \
# 35113       COVER_6_ZONE    Converging                  0
# 32625       COVER_2_ZONE    Converging                  0
# 20791       COVER_2_ZONE    Converging                  0
# 45910       COVER_3_ZONE    Converging                  0
# 36032       COVER_6_ZONE    Converging                  0
# 12973       COVER_6_ZONE    Converging                  0
# 43572       COVER_3_ZONE    Converging                  0
# 11603       COVER_3_ZONE    Converging                  0
# 12093       COVER_3_ZONE    Converging                  0
# 12170       COVER_2_ZONE    Converging                  0
# 23697       COVER_2_ZONE    Converging                  0
# 45017       COVER_2_ZONE    Converging                  0
# 36777        COVER_1_MAN    Converging                  1
# 2713         COVER_0_MAN    Converging                  0
# 45193       COVER_4_ZONE    Converging                  0
# 11976       COVER_6_ZONE    Converging                  0
# 19203        COVER_2_MAN    Converging                  0
# 12354       COVER_3_ZONE    Converging                  0
# 34856       COVER_4_ZONE    Converging                  1
# 7412        COVER_4_ZONE    Converging                  0
# 37406       COVER_4_ZONE    Converging                  0
# 40830       COVER_3_ZONE    Converging                  0
# 37427       COVER_4_ZONE    Converging                  0
# 19922       COVER_4_ZONE    Converging                  0
# 37785       COVER_3_ZONE    Converging                  0
# 45755       COVER_3_ZONE    Converging                  0
# 26549       COVER_4_ZONE    Converging                  0
# 12774       COVER_3_ZONE    Converging                  0
# 21718        COVER_1_MAN    Converging                  0
# 4164        COVER_4_ZONE    Converging                  0
# 1141         COVER_1_MAN    Converging                  0
# 7611        COVER_2_ZONE    Converging                  0
# 42354       COVER_2_ZONE    Converging                  0
# 42771       COVER_6_ZONE    Converging                  0
# 1144         COVER_1_MAN    Converging                  0
# 17185       COVER_3_ZONE    Converging                  0
# 41410        COVER_1_MAN    Converging                  0
# 45188       COVER_4_ZONE    Converging                  0
# 23866       COVER_3_ZONE    Converging                  0
# 36298       COVER_3_ZONE    Converging                  0
#
#        targeted_receiver_id
# 35113                 53486
# 32625                 52451
# 20791                 43454
# 45910                 46256
# 36032                 54473
# 12973                 54475
# 43572                 55899
# 11603                 54608
# 12093                 43454
# 12170                 47834
# 23697                 46130
# 45017                 47847
# 36777                 54614
# 2713                  46213
# 45193                 46192
# 11976                 53435
# 19203                 42397
# 12354                 42489
# 34856                 46109
# 7412                  56024
# 37406                 46155
# 40830                 55887
# 37427                 52441
# 19922                 43344
# 37785                 47808
# 45755                 52451
# 26549                 47849
# 12774                 42347
# 21718                 41282
# 4164                  54536
# 1141                  52430
# 7611                  48646
# 42354                 41246
# 42771                 55939
# 1144                  52430
# 17185                 56357
# 41410                 54517
# 45188                 46192
# 23866                 44835
# 36298                 52430

# %%
catch_probabilities[
  (catch_probabilities['game_id'] == 2023101500)&
  (catch_probabilities['play_id'] == 2935)
  # & (catch_probabilities['nfl_id'] == 1563)
  ]
# Out:
#          game_id  play_id  baseline_prob  real_prob     delta pass_result  \
# 3558  2023101500     2935       0.065595   0.298792  0.233197          IN
#
#       yards_gained  season  week home_team_abbr visitor_team_abbr  \
# 3558             0    2023     6            TEN               BAL
#
#                                        play_description  quarter game_clock  \
# 3558  (4:43) (Shotgun) R.Tannehill pass deep right i...        3      04:43
#
#       passer_nfl_id  num_output_frames num_output_frames_bin possession_team  \
# 3558        38538.0                 20                MEDIUM             TEN
#
#      defensive_team down_and_distance receiver_alignment  \
# 3558            BAL         3rd_short                2x1
#
#      route_of_targeted_receiver route_type_of_targeted_receiver  pass_length  \
# 3558                     CORNER                        VERTICAL           28
#
#      pass_length_bin dropback_type team_coverage_man_zone team_coverage_type
# 3558            DEEP   TRADITIONAL          ZONE_COVERAGE       COVER_3_ZONE

# %%
local_submission[(local_submission['game_id'] == 2023101500) &
                 (local_submission['play_id'] == 2935) &
                 (local_submission['nfl_id'] == 52627)
                 ]
# Out:
#            game_id  play_id  nfl_id  frame_id     pred_x     pred_y  actual_x  \
# 162154  2023101500     2935   52627         1  83.476159  24.071930     83.46
# 162155  2023101500     2935   52627         2  83.904461  23.651369     83.87
# 162156  2023101500     2935   52627         3  84.330541  23.185679     84.27
# 162157  2023101500     2935   52627         4  84.743077  22.675965     84.65
# 162158  2023101500     2935   52627         5  85.139784  22.129587     85.01
# 162159  2023101500     2935   52627         6  85.530197  21.530693     85.35
# 162160  2023101500     2935   52627         7  85.898468  20.899870     85.67
# 162161  2023101500     2935   52627         8  86.250411  20.236954     85.97
# 162162  2023101500     2935   52627         9  86.586353  19.543356     86.26
# 162163  2023101500     2935   52627        10  86.906035  18.825362     86.52
# 162164  2023101500     2935   52627        11  87.216048  18.083150     86.77
# 162165  2023101500     2935   52627        12  87.521509  17.337237     87.00
# 162166  2023101500     2935   52627        13  87.806834  16.577290     87.24
# 162167  2023101500     2935   52627        14  88.081078  15.811382     87.47
# 162168  2023101500     2935   52627        15  88.345934  15.045773     87.69
# 162169  2023101500     2935   52627        16  88.620028  14.268627     87.92
# 162170  2023101500     2935   52627        17  88.853369  13.527074     88.15
# 162171  2023101500     2935   52627        18  89.090687  12.762745     88.38
# 162172  2023101500     2935   52627        19  89.352770  12.031449     88.62
# 162173  2023101500     2935   52627        20  89.581895  11.288470     88.86
#
#         actual_y     error
# 162154     24.08  0.018062
# 162155     23.65  0.034488
# 162156     23.17  0.062538
# 162157     22.63  0.103808
# 162158     22.05  0.152243
# 162159     21.43  0.206422
# 162160     20.78  0.258005
# 162161     20.10  0.312068
# 162162     19.40  0.356451
# 162163     18.68  0.412496
# 162164     17.94  0.468456
# 162165     17.20  0.539264
# 162166     16.46  0.578842
# 162167     15.73  0.616473
# 162168     15.01  0.656909
# 162169     14.31  0.701249
# 162170     13.64  0.712376
# 162171     12.99  0.746137
# 162172     12.37  0.807199
# 162173     11.77  0.867758

# %%
train_input[(train_input['game_id'] == 2023101500) &
            (train_input['play_id'] == 2935) & 
            (train_input['nfl_id']== 52627)]
# Out:
#           game_id  play_id  player_to_predict  nfl_id  frame_id  \
# 23154  2023101500     2935               True   52627         1
# 23155  2023101500     2935               True   52627         2
# 23156  2023101500     2935               True   52627         3
# 23157  2023101500     2935               True   52627         4
# 23158  2023101500     2935               True   52627         5
# 23159  2023101500     2935               True   52627         6
# 23160  2023101500     2935               True   52627         7
# 23161  2023101500     2935               True   52627         8
# 23162  2023101500     2935               True   52627         9
# 23163  2023101500     2935               True   52627        10
# 23164  2023101500     2935               True   52627        11
# 23165  2023101500     2935               True   52627        12
# 23166  2023101500     2935               True   52627        13
# 23167  2023101500     2935               True   52627        14
# 23168  2023101500     2935               True   52627        15
# 23169  2023101500     2935               True   52627        16
# 23170  2023101500     2935               True   52627        17
# 23171  2023101500     2935               True   52627        18
# 23172  2023101500     2935               True   52627        19
# 23173  2023101500     2935               True   52627        20
# 23174  2023101500     2935               True   52627        21
# 23175  2023101500     2935               True   52627        22
# 23176  2023101500     2935               True   52627        23
# 23177  2023101500     2935               True   52627        24
# 23178  2023101500     2935               True   52627        25
# 23179  2023101500     2935               True   52627        26
# 23180  2023101500     2935               True   52627        27
# 23181  2023101500     2935               True   52627        28
#
#       play_direction  absolute_yardline_number player_name player_height  \
# 23154          right                        62  Geno Stone          5-11
# 23155          right                        62  Geno Stone          5-11
# 23156          right                        62  Geno Stone          5-11
# 23157          right                        62  Geno Stone          5-11
# 23158          right                        62  Geno Stone          5-11
# 23159          right                        62  Geno Stone          5-11
# 23160          right                        62  Geno Stone          5-11
# 23161          right                        62  Geno Stone          5-11
# 23162          right                        62  Geno Stone          5-11
# 23163          right                        62  Geno Stone          5-11
# 23164          right                        62  Geno Stone          5-11
# 23165          right                        62  Geno Stone          5-11
# 23166          right                        62  Geno Stone          5-11
# 23167          right                        62  Geno Stone          5-11
# 23168          right                        62  Geno Stone          5-11
# 23169          right                        62  Geno Stone          5-11
# 23170          right                        62  Geno Stone          5-11
# 23171          right                        62  Geno Stone          5-11
# 23172          right                        62  Geno Stone          5-11
# 23173          right                        62  Geno Stone          5-11
# 23174          right                        62  Geno Stone          5-11
# 23175          right                        62  Geno Stone          5-11
# 23176          right                        62  Geno Stone          5-11
# 23177          right                        62  Geno Stone          5-11
# 23178          right                        62  Geno Stone          5-11
# 23179          right                        62  Geno Stone          5-11
# 23180          right                        62  Geno Stone          5-11
# 23181          right                        62  Geno Stone          5-11
#
#        player_weight player_birth_date player_position player_side  \
# 23154            210        1999-04-19              FS     Defense
# 23155            210        1999-04-19              FS     Defense
# 23156            210        1999-04-19              FS     Defense
# 23157            210        1999-04-19              FS     Defense
# 23158            210        1999-04-19              FS     Defense
# 23159            210        1999-04-19              FS     Defense
# 23160            210        1999-04-19              FS     Defense
# 23161            210        1999-04-19              FS     Defense
# 23162            210        1999-04-19              FS     Defense
# 23163            210        1999-04-19              FS     Defense
# 23164            210        1999-04-19              FS     Defense
# 23165            210        1999-04-19              FS     Defense
# 23166            210        1999-04-19              FS     Defense
# 23167            210        1999-04-19              FS     Defense
# 23168            210        1999-04-19              FS     Defense
# 23169            210        1999-04-19              FS     Defense
# 23170            210        1999-04-19              FS     Defense
# 23171            210        1999-04-19              FS     Defense
# 23172            210        1999-04-19              FS     Defense
# 23173            210        1999-04-19              FS     Defense
# 23174            210        1999-04-19              FS     Defense
# 23175            210        1999-04-19              FS     Defense
# 23176            210        1999-04-19              FS     Defense
# 23177            210        1999-04-19              FS     Defense
# 23178            210        1999-04-19              FS     Defense
# 23179            210        1999-04-19              FS     Defense
# 23180            210        1999-04-19              FS     Defense
# 23181            210        1999-04-19              FS     Defense
#
#               player_role      x      y     s     a     dir       o  \
# 23154  Defensive Coverage  75.50  23.78  0.33  0.74   69.03  288.98
# 23155  Defensive Coverage  75.54  23.79  0.33  0.73   83.54  292.91
# 23156  Defensive Coverage  75.57  23.79  0.38  0.46   84.97  297.61
# 23157  Defensive Coverage  75.61  23.80  0.46  0.42   84.74  300.00
# 23158  Defensive Coverage  75.67  23.80  0.62  0.84   83.25  303.59
# 23159  Defensive Coverage  75.74  23.82  0.83  1.27   79.66  307.14
# 23160  Defensive Coverage  75.84  23.83  1.18  2.05   79.38  307.76
# 23161  Defensive Coverage  75.97  23.86  1.54  2.64   78.01  309.70
# 23162  Defensive Coverage  76.13  23.89  1.86  2.70   77.19  315.62
# 23163  Defensive Coverage  76.34  23.94  2.25  2.87   75.57  320.67
# 23164  Defensive Coverage  76.57  24.00  2.52  2.53   74.99  323.08
# 23165  Defensive Coverage  76.84  24.10  2.92  2.67   71.19  326.35
# 23166  Defensive Coverage  77.13  24.20  3.19  2.36   69.31  327.55
# 23167  Defensive Coverage  77.43  24.33  3.41  1.97   67.48  327.55
# 23168  Defensive Coverage  77.76  24.47  3.61  1.69   65.40  326.03
# 23169  Defensive Coverage  78.10  24.63  3.86  1.46   65.75  308.18
# 23170  Defensive Coverage  78.46  24.79  3.98  1.21   66.54  286.49
# 23171  Defensive Coverage  78.83  24.94  4.08  0.98   68.14  275.69
# 23172  Defensive Coverage  79.21  25.09  4.14  1.08   70.28  268.67
# 23173  Defensive Coverage  79.61  25.22  4.16  2.23   76.19  262.27
# 23174  Defensive Coverage  80.01  25.30  4.14  2.54   80.19  261.08
# 23175  Defensive Coverage  80.42  25.35  4.14  3.16   86.45  256.37
# 23176  Defensive Coverage  80.84  25.35  4.24  3.52   93.02  249.74
# 23177  Defensive Coverage  81.28  25.28  4.40  4.11  101.18  245.41
# 23178  Defensive Coverage  81.72  25.17  4.61  4.33  107.81  248.45
# 23179  Defensive Coverage  82.15  24.99  4.78  4.31  114.13  251.44
# 23180  Defensive Coverage  82.59  24.77  5.00  3.99  119.31  252.02
# 23181  Defensive Coverage  83.04  24.45  5.53  4.83  126.62  244.31
#
#        num_frames_output  ball_land_x  ball_land_y
# 23154                 20    88.629997        11.36
# 23155                 20    88.629997        11.36
# 23156                 20    88.629997        11.36
# 23157                 20    88.629997        11.36
# 23158                 20    88.629997        11.36
# 23159                 20    88.629997        11.36
# 23160                 20    88.629997        11.36
# 23161                 20    88.629997        11.36
# 23162                 20    88.629997        11.36
# 23163                 20    88.629997        11.36
# 23164                 20    88.629997        11.36
# 23165                 20    88.629997        11.36
# 23166                 20    88.629997        11.36
# 23167                 20    88.629997        11.36
# 23168                 20    88.629997        11.36
# 23169                 20    88.629997        11.36
# 23170                 20    88.629997        11.36
# 23171                 20    88.629997        11.36
# 23172                 20    88.629997        11.36
# 23173                 20    88.629997        11.36
# 23174                 20    88.629997        11.36
# 23175                 20    88.629997        11.36
# 23176                 20    88.629997        11.36
# 23177                 20    88.629997        11.36
# 23178                 20    88.629997        11.36
# 23179                 20    88.629997        11.36
# 23180                 20    88.629997        11.36
# 23181                 20    88.629997        11.36

# %%
filtered[filtered['nfl_id'] == 45004].sort_values('delta', ascending= False).head(20)
# Out:
#           game_id  play_id  nfl_id         player_role  baseline_prob  \
# 5830   2023112605     1823   45004  Defensive Coverage       0.463136
# 23626  2023120304     1700   45004  Defensive Coverage       0.104038
# 36030  2023121709     2202   45004  Defensive Coverage       0.207544
# 39166  2023092409      570   45004  Defensive Coverage       0.845544
# 28124  2023091800     1340   45004  Defensive Coverage       0.012735
# 27054  2024010705      519   45004  Defensive Coverage       0.633150
# 5867   2023112605     2967   45004  Defensive Coverage       0.565379
# 22546  2023111900     2410   45004  Defensive Coverage       0.125161
# 7379   2023122403     1323   45004  Defensive Coverage       0.589858
# 7496   2023122403     4065   45004  Defensive Coverage       0.425641
# 28082  2023091800      148   45004  Defensive Coverage       0.341319
# 16238  2023121005     3300   45004  Defensive Coverage       0.206867
# 41497  2023110508     1285   45004  Defensive Coverage       0.483109
# 27120  2024010705     3000   45004  Defensive Coverage       0.656284
# 5885   2023112605     3355   45004  Defensive Coverage       0.367312
# 22473  2023111900      471   45004  Defensive Coverage       0.078472
# 8111   2023123106     1453   45004  Defensive Coverage       0.700108
# 5793   2023112605      634   45004  Defensive Coverage       0.589379
# 32667  2023110900     1593   45004  Defensive Coverage       0.499687
# 23668  2023120304     2588   45004  Defensive Coverage       0.114708
#
#        real_prob     delta  fold pass_result  yards_gained  season  week  \
# 5830    0.664395  0.201259     1           I             0    2023    12
# 23626   0.261975  0.157936     3          IN             0    2023    13
# 36030   0.329517  0.121973     4           I             0    2023    15
# 39166   0.890875  0.045331     5           C            20    2023     3
# 28124   0.051037  0.038302     4           I             0    2023     2
# 27054   0.645653  0.012503     3           I             0    2023    18
# 5867    0.576830  0.011450     1           C            19    2023    12
# 22546   0.135506  0.010345     3           C            12    2023    11
# 7379    0.597526  0.007668     1           C            13    2023    16
# 7496    0.428672  0.003031     1           C            36    2023    16
# 28082   0.343151  0.001832     4           I             0    2023     2
# 16238   0.208316  0.001449     2           C            44    2023    14
# 41497   0.484398  0.001289     5           C            19    2023     9
# 27120   0.657508  0.001224     3           I             0    2023    18
# 5885    0.367932  0.000620     1           C            22    2023    12
# 22473   0.078909  0.000437     3           I             0    2023    11
# 8111    0.700539  0.000431     1           C            48    2023    17
# 5793    0.589794  0.000415     1           C            25    2023    12
# 32667   0.499936  0.000250     4           C            15    2023    10
# 23668   0.114907  0.000199     3           I             0    2023    13
#
#       home_team_abbr visitor_team_abbr  \
# 5830             TEN               CAR
# 23626             TB               CAR
# 36030            CAR               ATL
# 39166            SEA               CAR
# 28124            CAR                NO
# 27054            CAR                TB
# 5867             TEN               CAR
# 22546            CAR               DAL
# 7379             CAR                GB
# 7496             CAR                GB
# 28082            CAR                NO
# 16238             NO               CAR
# 41497            CAR               IND
# 27120            CAR                TB
# 5885             TEN               CAR
# 22473            CAR               DAL
# 8111             JAX               CAR
# 5793             TEN               CAR
# 32667            CHI               CAR
# 23668             TB               CAR
#
#                                         play_description  quarter game_clock  \
# 5830   (1:05) (Shotgun) W.Levis pass incomplete short...        2      01:05
# 23626  (2:31) (Shotgun) B.Mayfield pass deep left int...        2      02:31
# 36030  (11:37) D.Ridder pass incomplete deep right to...        3      11:37
# 39166  (7:30) G.Smith pass deep left to D.Metcalf to ...        1      07:30
# 28124  (11:03) (No Huddle, Shotgun) D.Carr pass incom...        2      11:03
# 27054  (5:56) (Shotgun) B.Mayfield pass incomplete de...        1      05:56
# 5867   (:24) W.Levis pass deep left to D.Hopkins push...        3      00:24
# 22546  (12:57) D.Prescott pass short right to B.Cooks...        3      12:57
# 7379   (10:28) (Shotgun) J.Love pass short middle to ...        2      10:28
# 7496   (2:39) (Shotgun) J.Love pass deep left to R.Do...        4      02:39
# 28082  (12:51) D.Carr pass incomplete deep right to C...        1      12:51
# 16238  (8:12) D.Carr pass deep right to A.Perry to CA...        4      08:12
# 41497  (10:27) (Shotgun) G.Minshew pass deep right to...        2      10:27
# 27120  (11:05) B.Mayfield pass incomplete short right...        4      11:05
# 5885   (11:33) (Shotgun) W.Levis pass deep right to C...        4      11:33
# 22473  (7:07) (Shotgun) D.Prescott pass incomplete de...        1      07:07
# 8111   (4:01) (Shotgun) C.Beathard pass deep right to...        2      04:01
# 5793   (1:56) W.Levis pass deep left to C.Okonkwo pus...        1      01:56
# 32667  (5:18) (Shotgun) T.Bagent pass short middle to...        2      05:18
# 23668  (10:10) B.Mayfield pass incomplete deep right ...        3      10:10
#
#       player_position  passer_nfl_id  num_output_frames num_output_frames_bin  \
# 5830               FS        55898.0                 19                MEDIUM
# 23626              FS        46070.0                 27                  LONG
# 36030              FS        54539.0                 14                MEDIUM
# 39166              FS        39987.0                 13                MEDIUM
# 28124              FS        41265.0                 23                  LONG
# 27054              FS        46070.0                 27                  LONG
# 5867               FS        55898.0                 15                MEDIUM
# 22546              FS        43424.0                 11                MEDIUM
# 7379               FS        52434.0                 11                MEDIUM
# 7496               FS        52434.0                 27                  LONG
# 28082              FS        41265.0                 17                MEDIUM
# 16238              FS        41265.0                 28                  LONG
# 41497              FS        47961.0                 14                MEDIUM
# 27120              FS        46070.0                  7                 QUICK
# 5885               FS        55898.0                 11                MEDIUM
# 22473              FS        43424.0                 14                MEDIUM
# 8111               FS        44916.0                 25                  LONG
# 5793               FS        55898.0                 23                  LONG
# 32667              FS        56167.0                 11                MEDIUM
# 23668              FS        46070.0                 22                  LONG
#
#       possession_team defensive_team down_and_distance receiver_alignment  \
# 5830              TEN            CAR        3rd_medium                3x1
# 23626              TB            CAR         3rd_short                3x1
# 36030             ATL            CAR          2nd_long                2x1
# 39166             SEA            CAR          1st_long                2x2
# 28124              NO            CAR          2nd_long                2x2
# 27054              TB            CAR        3rd_medium                3x1
# 5867              TEN            CAR          1st_long                2x1
# 22546             DAL            CAR        2nd_medium                2x1
# 7379               GB            CAR          1st_long                2x2
# 7496               GB            CAR        3rd_medium                2x2
# 28082              NO            CAR        2nd_medium                2x2
# 16238              NO            CAR          1st_long                3x1
# 41497             IND            CAR          2nd_long                2x2
# 27120              TB            CAR        2nd_medium                2x2
# 5885              TEN            CAR          1st_long                2x2
# 22473             DAL            CAR          1st_long                3x2
# 8111              JAX            CAR        2nd_medium                2x2
# 5793              TEN            CAR          1st_long                2x1
# 32667             CHI            CAR          4th_down                3x1
# 23668              TB            CAR          1st_long                2x2
#
#       route_of_targeted_receiver route_type_of_targeted_receiver  pass_length  \
# 5830                       WHEEL                        VERTICAL           15
# 23626                         GO                        VERTICAL           28
# 36030                     CORNER                        VERTICAL           19
# 39166                      HITCH                      STOP_HITCH           18
# 28124                         IN                        IN_BREAK           23
# 27054                         GO                        VERTICAL           38
# 5867                         OUT                       OUT_BREAK           18
# 22546                      HITCH                      STOP_HITCH           12
# 7379                          IN                        IN_BREAK           13
# 7496                          GO                        VERTICAL           33
# 28082                        OUT                       OUT_BREAK           17
# 16238                       POST                        VERTICAL           44
# 41497                     CORNER                        VERTICAL           17
# 27120                      CROSS                        IN_BREAK           13
# 5885                          IN                        IN_BREAK           17
# 22473                       POST                        VERTICAL           23
# 8111                          GO                        VERTICAL           35
# 5793                       WHEEL                        VERTICAL           17
# 32667                         IN                        IN_BREAK           15
# 23668                     CORNER                        VERTICAL           29
#
#       pass_length_bin           dropback_type team_coverage_man_zone  \
# 5830     INTERMEDIATE             TRADITIONAL           MAN_COVERAGE
# 23626            DEEP             TRADITIONAL          ZONE_COVERAGE
# 36030    INTERMEDIATE  DESIGNED_ROLLOUT_RIGHT          ZONE_COVERAGE
# 39166    INTERMEDIATE             TRADITIONAL          ZONE_COVERAGE
# 28124            DEEP             TRADITIONAL          ZONE_COVERAGE
# 27054            DEEP             TRADITIONAL          ZONE_COVERAGE
# 5867     INTERMEDIATE             TRADITIONAL          ZONE_COVERAGE
# 22546    INTERMEDIATE             TRADITIONAL          ZONE_COVERAGE
# 7379     INTERMEDIATE             TRADITIONAL          ZONE_COVERAGE
# 7496             DEEP             TRADITIONAL          ZONE_COVERAGE
# 28082    INTERMEDIATE             TRADITIONAL          ZONE_COVERAGE
# 16238            DEEP             TRADITIONAL          ZONE_COVERAGE
# 41497    INTERMEDIATE             TRADITIONAL          ZONE_COVERAGE
# 27120    INTERMEDIATE             TRADITIONAL          ZONE_COVERAGE
# 5885     INTERMEDIATE             TRADITIONAL          ZONE_COVERAGE
# 22473            DEEP             TRADITIONAL           MAN_COVERAGE
# 8111             DEEP             TRADITIONAL           MAN_COVERAGE
# 5793     INTERMEDIATE             TRADITIONAL          ZONE_COVERAGE
# 32667    INTERMEDIATE             TRADITIONAL          ZONE_COVERAGE
# 23668            DEEP             TRADITIONAL          ZONE_COVERAGE
#
#       team_coverage_type defender_type  potential_contact  \
# 5830         COVER_1_MAN    Converging                  0
# 23626       COVER_3_ZONE    Converging                  0
# 36030       COVER_6_ZONE    Converging                  0
# 39166       COVER_6_ZONE    Converging                  0
# 28124       COVER_3_ZONE    Converging                  0
# 27054       COVER_6_ZONE    Converging                  0
# 5867        COVER_6_ZONE    Converging                  0
# 22546       COVER_3_ZONE    Converging                  0
# 7379        COVER_3_ZONE    Converging                  0
# 7496        COVER_3_ZONE    Converging                  0
# 28082       COVER_3_ZONE    Converging                  0
# 16238       COVER_3_ZONE    Converging                  0
# 41497       COVER_3_ZONE    Converging                  0
# 27120       COVER_3_ZONE    Converging                  0
# 5885        COVER_3_ZONE    Converging                  0
# 22473        COVER_1_MAN    Converging                  0
# 8111         COVER_1_MAN    Converging                  0
# 5793        COVER_6_ZONE    Converging                  0
# 32667       COVER_3_ZONE    Converging                  0
# 23668       COVER_6_ZONE    Converging                  0
#
#        targeted_receiver_id
# 5830                  55946
# 23626                 41233
# 36030                 54473
# 39166                 47847
# 28124                 43336
# 27054                 41233
# 5867                  39973
# 22546                 41246
# 7379                  54597
# 7496                  54597
# 28082                 54476
# 16238                 56060
# 41497                 54657
# 27120                 56056
# 5885                  43396
# 22473                 52425
# 8111                  44978
# 5793                  54608
# 32667                 55998
# 23668                 44896

# %%
denom = filtered.groupby('nfl_id').count().reset_index().sort_values('play_id', ascending = False)[['nfl_id','play_id']]
num = filtered[filtered['delta'] < -.01].groupby('nfl_id').count().reset_index().sort_values('play_id', ascending = False)[['nfl_id','play_id']]
f = num.merge(denom, on = 'nfl_id').rename(columns = {'play_id_x': 'num',
                                                      'play_id_y': 'denom'})
f['rate'] = f['num']/f['denom']
f.sort_values('num', ascending = False).head(1)
# Out:
#    nfl_id  num  denom      rate
# 0   53554   11     81  0.135802

# %%
test = pd.read_csv('./outputs/defender_impact_log_wr.csv')
print(test.shape)
test = test.merge(supplementary_data[['game_id','play_id','pass_result', 'yards_gained', 'season','week','home_team_abbr','visitor_team_abbr','play_description', 'quarter','game_clock']],
        on=['game_id','play_id'], how='left')
test = test.merge(train_input[['nfl_id','player_name']].drop_duplicates(), on='nfl_id', how='left')
test[test['nfl_id'] == 45004].sort_values('delta').head(2)
# Out:
# (46045, 8)
#           game_id  play_id  nfl_id         player_role  baseline_prob  \
# 8100   2023123106     1090   45004  Defensive Coverage       0.436152
# 16227  2023121005     3029   45004  Defensive Coverage       0.472147
#
#        real_prob     delta  fold pass_result  yards_gained  season  week  \
# 8100    0.186293 -0.249860     1           C             4    2023    17
# 16227   0.244031 -0.228116     2           I             0    2023    14
#
#       home_team_abbr visitor_team_abbr  \
# 8100             JAX               CAR
# 16227             NO               CAR
#
#                                         play_description  quarter game_clock  \
# 8100   (10:38) (Shotgun) C.Beathard pass short right ...        2      10:38
# 16227  (12:27) (Shotgun) D.Carr pass incomplete short...        4      12:27
#
#         player_name
# 8100   Xavier Woods
# 16227  Xavier Woods
